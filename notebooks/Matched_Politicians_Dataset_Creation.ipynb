# %% [markdown]
# This notebook contains Helen's code for building the combined FEC / DC Inbox data set.

# %%
# import libraries
import pandas as pd
import numpy as np
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import unicodedata
import ftfy
import ast

# %%
# Set colors and formats for figures

# Palette for party breakdowns
# Uses the colorblind-safe RedBlues palette from Regenbogen
# Source: https://github.com/nrennie/PrettyCols
overall_color = "#acacac"
dem_light_color = "#93C6E1"
rep_light_color = "#D79C9C"
dem_med_color = "#5F93AC"
rep_med_color = "#C66969"
dem_dark_color = "#2E627A"
rep_dark_color = "#B53737"

# Palette for other breakdowns
# Uses the colorblind-safe VincentvanGogh_1 palette from Regenbogen
# Source: https://github.com/tylerlittlefield/lisa
breakdown_color1 = "#A7A651"
breakdown_color2 = "#E0BA7A"
breakdown_color3 = "#9BA7B0"
breakdown_color4 = "#BFB9C9"


# Optional alternative font settings
axis_titlesize = 10
axis_labelsize = 9
facet_titlesize = 9
caption_size = 8

# Global Seaborn style default settings
sns.set(
    style="whitegrid",
    rc={
        "axes.labelsize": axis_labelsize,   # x/y axis labels
        "xtick.labelsize": axis_labelsize,   # tick labels
        "ytick.labelsize": axis_labelsize,
    }
)

# %%
# Read in the raw DCInbox table

dcinbox_raw_df = pd.read_csv(
    "../data/dcinbox/dcinbox_export_114.csv",
    # sep = ",",            # columns are separated by commas
    # encoding = "latin1",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    engine = 'python'    # This might be able to handle very long messages better
)

# Remove all unnamed columns, because they're messing up the read of the file
unnamed = dcinbox_raw_df.columns.str.contains('^Unnamed')
dcinbox_clean_columns_df = dcinbox_raw_df.loc[:, ~unnamed].copy()

print(len(dcinbox_clean_columns_df))
dcinbox_clean_columns_df.head()
# Out:
# 24224
#                                             Subject  \
# 0                                   Happy New Year!
# 1                                   Happy New Year!
# 2  OH-12 Update / A Look Back at the 114th Congress
# 3              The Leader's Daily Schedule - 1/3/17
# 4                         What I've Been Working On
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  Click here to open this e-mail in its own browser window Click here to open a plain text version of this email The Webster Wire Listening to Central Florida Dear Friends: From participating in local festivities in celebration of the season, to meeting with constituents, participating in food banks and toy drives, to welcoming family into town, it's been a great couple weeks in the district. The sight of a child's eyes lighting up at Christmas is joy that never grows old. _______________ Wreathes Across America ensures that no veteran who has passed is forgotten at Christmas and that their place of final rest is honored. It was a privilege to participate in their ceremony and wreathe laying at the Lone Oak Cemetery in Leesburg. We owe our military a debt we can never repay. _______________ Since their dedication just a few months ago, the Leesburg Salvation Army is doing great work in a short amount of time. I was honored to join them earlier this week to serve a hot breakfast to their community members and bell ringers. Thank you Lieutenant William Conley and volunteers for your service! _______________ If you want to be inspired and encouraged this season, spend some time with Don Diamont and his team that serves at the Leesburg Food Bank. With the help of local businesses such as Publix and residents, they put together food and gifts for those in need in the community. Thank you Don for allowing me to join you all in handing out baskets full of all the fixings for a delicious Christmas Dinner! _______________ Thank you to Ohio State students who teamed up with Habitat for Humanity during their winter break. I got to witness firsthand the results of their yardwork and see
...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       The Leader's Daily Schedule - 1/3/17 Kevin McCarthy - Majority Leader - Leader's Daily Schedule Leader's Daily Schedule TUESDAY, JANUARY 3RD On Tuesday, the 114th Congress will meet at 11:00 a.m. for legislative business and adjourn sine die. The House will convene for the start of the 115th Congress at 12:00 p.m. There will be a recorded quorum call at 12:00 p.m. following the Prayer and Pledge of Allegiance. Last votes expected: TBD. Election of the Speaker of the House Swearing-in of Members and Delegates . 5 - Adopting Rules for the One Hundred Fifteenth Congress ( Privileged Resolution ) (Sponsored by Rep. Kevin McCarthy) Legislation Considered Under Suspension of the Rules: 1) H.R. ___ - Ensuring VA Employee Accountability Act (Sponsored by Rep. Ryan Costello / Veterans Affairs Committee) 2) H.R. ___ - Biological Implant Tracking and Veteran Safety Act of 2017 (Sponsored by Rep. Phil Roe / Veterans Affairs Committee) Printable PDF Majority Leader Floor Office • H-107 U.S. Capitol Click Here to view this email i ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Click here to open this e-mail in its own browser window Click here to open a plain text version of this email News from Representative David Cicilline SERVING YOU | MEDIA CENTER | LEGISLATIVE WORK | OUR DISTRICT January 2, 2017 Dear Friend, Tomorrow, I will begin my fourth term representing you in the United States Congress. I'm honored by the trust you've placed in me to deliver results and get things done for our state. I wanted to take a moment to share some of the work we accomplished over the past two years, which I've compiled in the infographic below: Feel free to forward this email or share this infographic on social media with your friends and family. And for more information, you can visit my website at . I look forward to continuing our work together and hearing from you over the next two years. Warm Regards, David Cicilline Member of Congress CONNECT WITH ME Washington D.C. Office 2244 Rayburn HOB Washington, DC 20515 Phone: (202) 225-4911 Fax: (202) 225-3290 Pawtucket Office 1070 Main Street, Suite 300 Pawtucket, RI 02860 Phone: ...
#
#   Unix Timestamp BioGuide ID Congress First Name  Last Name Date of Birth  \
# 0    1.48339E+12     W000806      114     Daniel    Webster       4/27/49
# 1    1.48338E+12     I000056      114    Darrell       Issa       11/1/53
# 2    1.48338E+12     T000462      114    Patrick     Tiberi      10/21/62
# 3    1.48337E+12     M001165      114      Kevin   McCarthy       1/26/65
# 4    1.48337E+12     C001084      114      David  Cicilline       7/15/61
#
#   Gender State District       Party Chamber Nickname      ID
# 0      M    FL       10  Republican   House      NaN  136125
# 1      M    CA       49  Republican   House      NaN  136126
# 2      M    OH       12  Republican   House      Pat  136127
# 3      M    CA       23  Republican   House      NaN  136128
# 4      M    RI        1    Democrat   House      NaN  136129

# %%
# QC to make sure special characters are coming in okay in DC Inbox data

mask = dcinbox_clean_columns_df["Last Name"].str.contains(r'[^\x00-\x7F]', regex=True, na=False)
special_names = dcinbox_clean_columns_df[mask]

# Select only first and last name, and keep unique combinations
allowed_parties = ["Democrat", "Republican", "Other"]
unique_names = special_names[special_names["Party"].isin(allowed_parties)][["First Name", "Last Name", "Party"]].drop_duplicates()

print(unique_names)
# Out:
#      First Name  Last Name     Party
# 216        Tony   Cárdenas  Democrat
# 284       Linda    Sánchez  Democrat
# 512        Beto   O’Rourke  Democrat
# 4752      Nydia  Velázquez  Democrat
# 8418        Ben      Luján  Democrat

# %%
# Column cleanup & additions for DC Inbox table

dcinbox_df = dcinbox_clean_columns_df.copy()

# Convert unix timestamp to datetime
dcinbox_df["Date"] = pd.to_datetime(
    pd.to_numeric(dcinbox_df["Unix Timestamp"], errors="coerce"),
    unit="ms"
).dt.date

# Convert district to an integer and fill senators with 0 (not NaN)
dcinbox_df["District"] = (
    pd.to_numeric(dcinbox_df["District"], errors = "coerce")
    .fillna(0)
    .astype(int)
)

# create a column that is the uppercased, concatenated first and last name of the politician
# (for matching later to Open Secrets data)
dcinbox_df["Full Name"] = dcinbox_df["First Name"].str.upper() + " " + dcinbox_df["Last Name"].str.upper()

# Rename party to party full
# And then add a new party column that just is one character mapped to D, R, or O (Other)
dcinbox_df.rename(columns={"Party": "Party Full", "ID": "Newsletter ID"}, inplace=True)
dcinbox_df["Party"] = (
    dcinbox_df["Party Full"]
    .fillna("")
    .astype(str)
    .str[0]
    .str.upper()
    .map({"D": "D", "R": "R"})
    .fillna("O")
)

# Make sure state and party values are uppercased
dcinbox_df["State"] = dcinbox_df["State"].fillna("").str.strip().str.upper()
dcinbox_df["Party"] = dcinbox_df["Party"].str.upper()

# Drop unneeded columns
dcinbox_df = dcinbox_df.drop(
    columns=['Nickname', "BioGuide ID", "Unix Timestamp", "Party Full", "Congress", "First Name", "Last Name"],
    errors='ignore'
)

# Rename columns to make them clearer
dcinbox_df 

# Add a unique ID for each newsletter (based on the index row)
# dcinbox_df["newsletter_id"] = ["NL" + str(i).zfill(6) for i in range(1, len(dcinbox_df) + 1)]

print(len(dcinbox_df))
dcinbox_df.head()
# Out:
# 24224
#                                             Subject  \
# 0                                   Happy New Year!
# 1                                   Happy New Year!
# 2  OH-12 Update / A Look Back at the 114th Congress
# 3              The Leader's Daily Schedule - 1/3/17
# 4                         What I've Been Working On
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  Click here to open this e-mail in its own browser window Click here to open a plain text version of this email The Webster Wire Listening to Central Florida Dear Friends: From participating in local festivities in celebration of the season, to meeting with constituents, participating in food banks and toy drives, to welcoming family into town, it's been a great couple weeks in the district. The sight of a child's eyes lighting up at Christmas is joy that never grows old. _______________ Wreathes Across America ensures that no veteran who has passed is forgotten at Christmas and that their place of final rest is honored. It was a privilege to participate in their ceremony and wreathe laying at the Lone Oak Cemetery in Leesburg. We owe our military a debt we can never repay. _______________ Since their dedication just a few months ago, the Leesburg Salvation Army is doing great work in a short amount of time. I was honored to join them earlier this week to serve a hot breakfast to their community members and bell ringers. Thank you Lieutenant William Conley and volunteers for your service! _______________ If you want to be inspired and encouraged this season, spend some time with Don Diamont and his team that serves at the Leesburg Food Bank. With the help of local businesses such as Publix and residents, they put together food and gifts for those in need in the community. Thank you Don for allowing me to join you all in handing out baskets full of all the fixings for a delicious Christmas Dinner! _______________ Thank you to Ohio State students who teamed up with Habitat for Humanity during their winter break. I got to witness firsthand the results of their yardwork and see the vigor with which they tackled painting. It was a blessing to me to see their servant's heart and I know it touched the heart of the incoming homeowner. _______________ It has been an honor to serve the constituents of District 10 for the last six years. I am excited for what 2017 holds with the new administration and serving the constituents of District 11. Thank you and Happy New Year! Your servant, Daniel Webster Member of Congress Constituent Corner A constituent of Auburndale had received a letter from the VA alm
th Congress ( Privileged Resolution ) (Sponsored by Rep. Kevin McCarthy) Legislation Considered Under Suspension of the Rules: 1) H.R. ___ - Ensuring VA Employee Accountability Act (Sponsored by Rep. Ryan Costello / Veterans Affairs Committee) 2) H.R. ___ - Biological Implant Tracking and Veteran Safety Act of 2017 (Sponsored by Rep. Phil Roe / Veterans Affairs Committee) Printable PDF Majority Leader Floor Office • H-107 U.S. Capitol Click Here to view this email i ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Click here to open this e-mail in its own browser window Click here to open a plain text version of this email News from Representative David Cicilline SERVING YOU | MEDIA CENTER | LEGISLATIVE WORK | OUR DISTRICT January 2, 2017 Dear Friend, Tomorrow, I will begin my fourth term representing you in the United States Congress. I'm honored by the trust you've placed in me to deliver results and get things done for our state. I wanted to take a moment to share some of the work we accomplished over the past two years, which I've compiled in the infographic below: Feel free to forward this email or share this infographic on social media with your friends and family. And for more information, you can visit my website at . I look forward to continuing our work together and hearing from you over the next two years. Warm Regards, David Cicilline Member of Congress CONNECT WITH ME Washington D.C. Office 2244 Rayburn HOB Washington, DC 20515 Phone: (202) 225-4911 Fax: (202) 225-3290 Pawtucket Office 1070 Main Street, Suite 300 Pawtucket, RI 02860 Phone: ...
#
#   Date of Birth Gender State  District Chamber Newsletter ID        Date  \
# 0       4/27/49      M    FL        10   House        136125  2017-01-02
# 1       11/1/53      M    CA        49   House        136126  2017-01-02
# 2      10/21/62      M    OH        12   House        136127  2017-01-02
# 3       1/26/65      M    CA        23   House        136128  2017-01-02
# 4       7/15/61      M    RI         1   House        136129  2017-01-02
#
#          Full Name Party
# 0   DANIEL WEBSTER     R
# 1     DARRELL ISSA     R
# 2   PATRICK TIBERI     R
# 3   KEVIN MCCARTHY     R
# 4  DAVID CICILLINE     D

# %%
# Read in the matched politicians table (the output of the matching process)

column_names = ["target_id", "dcinbox_name", "fec_cid", "fec_name",
                "fec_party", "fec_state", "fec_district",
                "fec_cycle", "append_attribute2", "append_attribute3",
                "similarity_score", "matched_scorer"]

matched_pols_df = pd.read_csv(
    "../data/matched/matched_politicians_2016_75.csv",
    encoding = "latin1",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    names = column_names,
    header = 0
)

print(len(matched_pols_df))
matched_pols_df.head()
# Out:
# 396
#    target_id     dcinbox_name    fec_cid         fec_name fec_party fec_state  \
# 0        NaN   DANIEL WEBSTER  N00026335   DANIEL WEBSTER         R        FL
# 1        NaN     DARRELL ISSA  N00007017     DARRELL ISSA         R        CA
# 2        NaN   PATRICK TIBERI  N00009699       PAT TIBERI         R        OH
# 3        NaN   KEVIN MCCARTHY  N00028152   KEVIN MCCARTHY         R        CA
# 4        NaN  DAVID CICILLINE  N00032019  DAVID CICILLINE         D        RI
#
#    fec_district  fec_cycle  append_attribute2  append_attribute3  \
# 0            10       2016                NaN                NaN
# 1            49       2016                NaN                NaN
# 2            12       2016                NaN                NaN
# 3            23       2016                NaN                NaN
# 4             1       2016                NaN                NaN
#
#    similarity_score matched_scorer
# 0        100.000000         WRatio
# 1        100.000000         WRatio
# 2         83.333333         WRatio
# 3        100.000000         WRatio
# 4        100.000000         WRatio

# %%
# Fix the special characters in the matched politicians file back to their original form

# Function to fix special characters
def fix_latin1_encoding(text):
    if isinstance(text, str):
        # Convert string to bytes using latin1, then decode as utf-8
        try:
            return text.encode('latin1').decode('utf-8')
        except UnicodeDecodeError:
            # If it fails, just return original text
            return text
    return text

matched_pols_df["dcinbox_name"] = matched_pols_df["dcinbox_name"].apply(fix_latin1_encoding)

# Function to fix weird apostrophes (like in 'Beto O'Rourke')
def clean_names(text):
    if not isinstance(text, str):
        return text
    fixed = ftfy.fix_text(text) # ftfy is supposed to handle special characters well
    fixed = fixed.replace("€™", "'").replace("â€™", "'").replace("â€˜", "'") # But it didn't quite do it right for the apostrophes
    return fixed

matched_pols_df["dcinbox_name"] = matched_pols_df["dcinbox_name"].apply(clean_names)

# %%
# QC to make sure special characters are coming in okay in matched data file

beto_df = matched_pols_df[matched_pols_df["dcinbox_name"].str.contains("ROURKE")]
print(beto_df[["dcinbox_name", "fec_name"]])

mask = matched_pols_df["dcinbox_name"].str.contains(r'[^\x00-\x7F]', regex=True, na=False)
special_names = matched_pols_df[mask]

print(special_names[["dcinbox_name", "fec_name"]])
# Out:
#       dcinbox_name       fec_name
# 211  BETO O'ROURKE  BETO O'ROURKE
#         dcinbox_name         fec_name
# 62      ANDRÉ CARSON     ANDRE CARSON
# 108    RAÚL LABRADOR    RAUL LABRADOR
# 124    TONY CÁRDENAS    TONY CARDENAS
# 157    LINDA SÁNCHEZ    LINDA SANCHEZ
# 308     JOSÉ SERRANO   JOSE E SERRANO
# 325    RAÚL GRIJALVA  RAUL M GRIJALVA
# 338  NYDIA VELÁZQUEZ  NYDIA VELAZQUEZ
# 356        BEN LUJÁN      BEN R LUJAN
# 382   RUBÉN HINOJOSA   RUBEN HINOJOSA

# %%
# Read in the summarized FEC candidate contributions file

cand_contribs_raw_df = pd.read_csv(
    "../data/fec/candidate_contributions_2016.csv",
    encoding = "latin1"
)

# Drop the columns we don't need
cand_contribs_raw_df = cand_contribs_raw_df.drop(columns=['DistIDRunFor', 'DistIDCurr', "CurrCand", "CycleCand", "Party Original",
                                                  "NoPacs", "RecipCode", "CRPICO", "FECCandID"])

print(len(cand_contribs_raw_df))
cand_contribs_raw_df.head()
# Out:
# 94712
#    Cycle        CID   FirstLastP State  District Party contrib_date  \
# 0   2016  N00030768  MARTHA ROBY    AL         2     R   2015-02-11
# 1   2016  N00030768  MARTHA ROBY    AL         2     R   2015-02-18
# 2   2016  N00030768  MARTHA ROBY    AL         2     R   2015-02-26
# 3   2016  N00030768  MARTHA ROBY    AL         2     R   2015-03-02
# 4   2016  N00030768  MARTHA ROBY    AL         2     R   2015-03-11
#
#    contrib_count  contrib_amount
# 0              1           250.0
# 1              2          1478.0
# 2              1          2700.0
# 3             26         40350.0
# 4              1          1000.0

# %%
# Add averages for year and month to candidate contributions dataframe (for normalizing later)

# Rename columns so they are more consistent and won't cause confusion with columns in the DC Inbox data file
cand_contribs_raw_df = cand_contribs_raw_df.rename(columns={
    "Cycle": "fec_cycle",
    "CID": "fec_cid",
    "FirstLastP": "fec_name",
    "State": "fec_state",
    "District": "fec_district",
    "Party": "fec_party"    
})

# Set types on some columns
cand_contribs_raw_df["contrib_count"] = cand_contribs_raw_df["contrib_count"].fillna(0)
cand_contribs_raw_df["contrib_amount"] = cand_contribs_raw_df["contrib_amount"].fillna(0).astype(int)
cand_contribs_raw_df["contrib_date"] = pd.to_datetime(cand_contribs_raw_df["contrib_date"])

# Define the full date range we want to use (should match what's in the file anyway)
start_date = pd.Timestamp("2015-01-03")
end_date = pd.Timestamp("2017-01-02")
# num_days = (end_date - start_date).days + 1  # inclusive

# Filter records to target dates
mask = (cand_contribs_raw_df["contrib_date"] >= start_date) & (cand_contribs_raw_df["contrib_date"] <= end_date)
cand_contribs_df = cand_contribs_raw_df.loc[mask].copy()

# Calculate monthly fundraising averages per politician
cand_contribs_df['month_start'] = cand_contribs_df['contrib_date'].values.astype('datetime64[M]') # Figure out month start date based on newsletter date 
monthly_stats = ( # group contributions by name, state, district, party, month to calculate the averages for that grouping 
    cand_contribs_df.groupby(["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party", "month_start"], dropna=False)
    .agg(
        monthly_contrib_count=('contrib_count', 'sum'),
        monthly_contrib_amount=('contrib_amount', 'sum')
    )
    .reset_index()
)
monthly_stats['days_in_month'] = monthly_stats['month_start'].dt.days_in_month
monthly_stats['avg_daily_contrib_count_per_month'] = monthly_stats['monthly_contrib_count'] / monthly_stats['days_in_month']
monthly_stats['avg_daily_contrib_amount_per_month'] = monthly_stats['monthly_contrib_amount'] / monthly_stats['days_in_month']

# Merge in monthly averages for contribution counts and 
cand_contribs_df = cand_contribs_df.merge(
    monthly_stats[['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party', 'month_start',
                   'avg_daily_contrib_count_per_month', 'avg_daily_contrib_amount_per_month']],
    on=['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party', 'month_start'],
    how='left'
)

cand_contribs_df.head()
# Out:
#    fec_cycle    fec_cid     fec_name fec_state  fec_district fec_party  \
# 0       2016  N00030768  MARTHA ROBY        AL             2         R
# 1       2016  N00030768  MARTHA ROBY        AL             2         R
# 2       2016  N00030768  MARTHA ROBY        AL             2         R
# 3       2016  N00030768  MARTHA ROBY        AL             2         R
# 4       2016  N00030768  MARTHA ROBY        AL             2         R
#
#   contrib_date  contrib_count  contrib_amount month_start  \
# 0   2015-02-11              1             250  2015-02-01
# 1   2015-02-18              2            1478  2015-02-01
# 2   2015-02-26              1            2700  2015-02-01
# 3   2015-03-02             26           40350  2015-03-01
# 4   2015-03-11              1            1000  2015-03-01
#
#    avg_daily_contrib_count_per_month  avg_daily_contrib_amount_per_month
# 0                           0.142857                          158.142857
# 1                           0.142857                          158.142857
# 2                           0.142857                          158.142857
# 3                           1.838710                         3079.032258
# 4                           1.838710                         3079.032258

# %%
# Read in the newsletter emotion data

emotion_raw_df = pd.read_csv(
    "../data/emotion_scores/emotion_scores_dcinbox_114.csv",
    quotechar = '"',
    engine = "python"
)

print(len(emotion_raw_df))
emotion_raw_df.head()
# Out:
# 20582
#                   date first_name last_name  \
# 0  2015-01-03 10:13:20      Jason     Smith
# 1  2015-01-03 10:13:20      Henry   Cuellar
# 2  2015-01-03 13:00:00     Thomas    Massie
# 3  2015-01-04 11:13:20    Richard     Hanna
# 4  2015-01-04 11:13:20      Louie   Gohmert
#
#                                                                                                    subject  \
# 0                                               Congressman Jason Smith Capitol Report: The Year in Review
# 1                                                                                     Congressional Report
# 2  PRESS RELEASE: U.S. Representative Thomas Massie Announces He Will Not Vote to Re-elect Speaker Boehner
# 3                                                                                        News from Upstate
# 4                                               Rep. Louie Gohmert Announces Run for Speaker of the House
#
#          id  neutral_score  anger_score  joy_score  disgust_score  \
# 0  101001.0       0.816557     0.077309   0.065098       0.016893
# 1  101000.0       0.295221     0.005299   0.611964            NaN
# 2  100999.0       0.127798     0.014982        NaN            NaN
# 3  100997.0       0.946661          NaN   0.007175            NaN
# 4  100998.0       0.727625     0.024723   0.053230            NaN
#
#    sadness_score  surprise_score  fear_score
# 0       0.013856             NaN         NaN
# 1       0.010520        0.072892         NaN
# 2       0.785828        0.028497    0.027273
# 3       0.017156        0.013342    0.006780
# 4            NaN        0.015453    0.159192

# %%
# Reformat, rename, and add columns on emotion data

emotion_clean_df = emotion_raw_df.copy()

# use dcinbox formatted dates
emotion_clean_df['date'] = pd.to_datetime(emotion_clean_df['date']).dt.strftime('%Y-%m-%d')

# concatenate first and last names into uppercased full name
emotion_clean_df['full_name'] = emotion_clean_df['first_name'].fillna('') + ' ' + emotion_clean_df['last_name'].fillna('')
emotion_clean_df['full_name'] = emotion_clean_df['full_name'].str.strip()  
emotion_clean_df['full_name'] = emotion_clean_df['full_name'].str.upper()

# Rename the ID field to make it clearer what it is
emotion_clean_df = emotion_clean_df.rename(columns={"id": "newsletter_id"})

# Convert the ID field to an integer
emotion_clean_df['newsletter_id'] = pd.to_numeric(emotion_clean_df['newsletter_id'], errors='coerce').fillna(0).astype(int)

# Drop the columns we don't need
emotion_clean_df.drop(columns=['first_name', 'last_name', 'subject'], inplace=True)

print(len(emotion_clean_df))
emotion_clean_df.head()
# Out:
# 20582
#          date  newsletter_id  neutral_score  anger_score  joy_score  \
# 0  2015-01-03         101001       0.816557     0.077309   0.065098
# 1  2015-01-03         101000       0.295221     0.005299   0.611964
# 2  2015-01-03         100999       0.127798     0.014982        NaN
# 3  2015-01-04         100997       0.946661          NaN   0.007175
# 4  2015-01-04         100998       0.727625     0.024723   0.053230
#
#    disgust_score  sadness_score  surprise_score  fear_score      full_name
# 0       0.016893       0.013856             NaN         NaN    JASON SMITH
# 1            NaN       0.010520        0.072892         NaN  HENRY CUELLAR
# 2            NaN       0.785828        0.028497    0.027273  THOMAS MASSIE
# 3            NaN       0.017156        0.013342    0.006780  RICHARD HANNA
# 4            NaN            NaN        0.015453    0.159192  LOUIE GOHMERT

# %%
# Read in the topic/themes data

theme_raw_df = pd.read_csv(
    "../data/dcinbox/email_themes_dcinbox_114.csv",
    quotechar = '"',
    engine = "python"
)

print(len(theme_raw_df))
theme_raw_df.head()
# Out:
# 20487
#   first_name last_name       party  email_id  \
# 0      Jason     Smith  Republican  101001.0
# 1      Henry   Cuellar    Democrat  101000.0
# 2     Thomas    Massie  Republican  100999.0
# 3    Richard     Hanna  Republican  100997.0
# 4      Louie   Gohmert  Republican  100998.0
#
#                                                                                                    subject  \
# 0                                               Congressman Jason Smith Capitol Report: The Year in Review
# 1                                                                                     Congressional Report
# 2  PRESS RELEASE: U.S. Representative Thomas Massie Announces He Will Not Vote to Re-elect Speaker Boehner
# 3                                                                                        News from Upstate
# 4                                               Rep. Louie Gohmert Announces Run for Speaker of the House
#
#                                                                                                                                                                                                                                                                                                              matched_phrases  \
# 0  ['healthcare', 'health', 'second amendment', 'assistance', 'obama', 'president obama', 'legislation', 'bills', 'house', 'senate', 'congress', 'amendment', 'veterans', 'tax', 'economy', 'jobs', 'regulations', 'regulation', 'spending', 'budget', 'pipeline', 'epa', 'life', 'overreach', 'states', 'freedom', 'media']
# 1                                                                ['healthcare', 'health', 'education', 'student', 'benefit', 'house', 'congress', 'law', 'criminal justice', 'housing', 'community', 'neighborhood', 'veterans', 'economy', 'epa', 'life', 'christmas', 'government', 'states', 'american', 'press', 'news']
# 2                                                                                                                                                                          ['bills', 'house', 'congress', 'committee', 'vote', 'order', 'isis', 'spending', 'christmas', 'constitution', 'constitutional', 'media', 'press']
# 3                                                                                                                                                                                                                         ['student', 'house', 'congress', 'community', 'order', 'business', 'epa', 'supreme court', 'news']
# 4                                                                                                                                                   ['house', 'senate', 'congress', 'committee', 'vote', 'votes', 'majority', 'voter', 'election', 'crime', 'homeland security', 'terrorism', 'terror', 'power', 'american']
#
#                                                                                                                                                                                                                                                                                                           themes  \
# 0                                            ['National Security & Defense', 'Political Figures - Obama', 'Social Issues & Values', 'Healthcare', 'Social Safety Net & Entitlements', 'Government Overreach', 'Economy & Taxes', 'Congress & Legislation', 'Gun Policy', 'Media & Press', 'Energy Independence']
# 1  ['National Security & Defense', 'Social Issues & Values', 'Healthcare', 'Social Safety Net & Entitlements', 'Patriotic Rhetoric', 'Education', 'Government Overreach', 'Economy & Taxes', 'Congress & Legislation', 'Criminal Justice Reform', 'Housing & Community', 'Media & Press', 'Energy Independence']
# 2                                                                                                                                     ['Social Issues & Values', 'Terrorism & Foreign Threats', 'Government Overreach', 'Economy & Taxes', 'Law Enforcement & Crime', 'Congress & Legislation', 'Media & Press']
# 3                                                                                                                              ['Education', 'Economy & Taxes', 'Law Enforcement & Crime', 'Congress & Legislation', 'Supreme Court & Judiciary', 'Housing & Community', 'Media & Press', 'Energy Independence']
# 4                                                                                                                                  ['National Security & Defense', 'Terrorism & Foreign Threats', 'Voting Rights', 'Patriotic Rhetoric', 'Law Enforcement & Crime', 'Congress & Legislation', 'Executive Power']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Rep. Louie Gohmert Announces Run for Speaker of the House U.S. Congressman Louie Gohmert, Proudly Serving the First District of Texas January 4, 2015 Having trouble reading this email? Click here to view the plain text. Rep. Louie Gohmert Announces Run for Speaker of the House WASHINGTON, DC - Rep. Louie Gohmert (TX-01) released the following statement today regarding his decision to buck the status quo and challenge John Boehner in the race for House Speaker: "After the November elections gave Republicans control of the Senate, voters made clear they wanted change. There have been numerous examples of problematic Republican leadership, but we were hopeful our leaders got the voters' message. However, after our Speaker forced through the CRomnibus by passing it with Democratic votes and without time to read it, it seemed clear that we needed new leadership. There had been much discussion. But, until yesterday, no one had stepped up. I applaud my friend Rep. Ted Yoho for putting ...

# %%
# Reformat, rename, and add columns on themes data

theme_clean_df = theme_raw_df.copy()

# Convert the ID field to an integer
theme_clean_df['email_id'] = pd.to_numeric(theme_clean_df['email_id'], errors='coerce').fillna(0).astype(int)

# Rename the ID field to make it clearer what it is
theme_clean_df = theme_clean_df.rename(columns={"email_id": "newsletter_id", "email": "body_text"})

# Drop the columns we don't need
theme_clean_df.drop(columns=['first_name', 'last_name', 'subject', 'party', 'body_text'], inplace=True)

# Make a new column that converts the "themes" column (of strings) into a new column that actually has the themes as lists
theme_clean_df['themes_list'] = theme_clean_df['themes'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

theme_clean_df.head()
# Out:
#    newsletter_id  \
# 0         101001
# 1         101000
# 2         100999
# 3         100997
# 4         100998
#
#                                                                                                                                                                                                                                                                                                              matched_phrases  \
# 0  ['healthcare', 'health', 'second amendment', 'assistance', 'obama', 'president obama', 'legislation', 'bills', 'house', 'senate', 'congress', 'amendment', 'veterans', 'tax', 'economy', 'jobs', 'regulations', 'regulation', 'spending', 'budget', 'pipeline', 'epa', 'life', 'overreach', 'states', 'freedom', 'media']
# 1                                                                ['healthcare', 'health', 'education', 'student', 'benefit', 'house', 'congress', 'law', 'criminal justice', 'housing', 'community', 'neighborhood', 'veterans', 'economy', 'epa', 'life', 'christmas', 'government', 'states', 'american', 'press', 'news']
# 2                                                                                                                                                                          ['bills', 'house', 'congress', 'committee', 'vote', 'order', 'isis', 'spending', 'christmas', 'constitution', 'constitutional', 'media', 'press']
# 3                                                                                                                                                                                                                         ['student', 'house', 'congress', 'community', 'order', 'business', 'epa', 'supreme court', 'news']
# 4                                                                                                                                                   ['house', 'senate', 'congress', 'committee', 'vote', 'votes', 'majority', 'voter', 'election', 'crime', 'homeland security', 'terrorism', 'terror', 'power', 'american']
#
#                                                                                                                                                                                                                                                                                                           themes  \
# 0                                            ['National Security & Defense', 'Political Figures - Obama', 'Social Issues & Values', 'Healthcare', 'Social Safety Net & Entitlements', 'Government Overreach', 'Economy & Taxes', 'Congress & Legislation', 'Gun Policy', 'Media & Press', 'Energy Independence']
# 1  ['National Security & Defense', 'Social Issues & Values', 'Healthcare', 'Social Safety Net & Entitlements', 'Patriotic Rhetoric', 'Education', 'Government Overreach', 'Economy & Taxes', 'Congress & Legislation', 'Criminal Justice Reform', 'Housing & Community', 'Media & Press', 'Energy Independence']
# 2                                                                                                                                     ['Social Issues & Values', 'Terrorism & Foreign Threats', 'Government Overreach', 'Economy & Taxes', 'Law Enforcement & Crime', 'Congress & Legislation', 'Media & Press']
# 3                                                                                                                              ['Education', 'Economy & Taxes', 'Law Enforcement & Crime', 'Congress & Legislation', 'Supreme Court & Judiciary', 'Housing & Community', 'Media & Press', 'Energy Independence']
# 4                                                                                                                                  ['National Security & Defense', 'Terrorism & Foreign Threats', 'Voting Rights', 'Patriotic Rhetoric', 'Law Enforcement & Crime', 'Congress & Legislation', 'Executive Power']
#
#                                                                                                                                                                                                                                                                            themes_list
# 0                                        [National Security & Defense, Political Figures - Obama, Social Issues & Values, Healthcare, Social Safety Net & Entitlements, Government Overreach, Economy & Taxes, Congress & Legislation, Gun Policy, Media & Press, Energy Independence]
# 1  [National Security & Defense, Social Issues & Values, Healthcare, Social Safety Net & Entitlements, Patriotic Rhetoric, Education, Government Overreach, Economy & Taxes, Congress & Legislation, Criminal Justice Reform, Housing & Community, Media & Press, Energy Independence]
# 2                                                                                                                         [Social Issues & Values, Terrorism & Foreign Threats, Government Overreach, Economy & Taxes, Law Enforcement & Crime, Congress & Legislation, Media & Press]
# 3                                                                                                                    [Education, Economy & Taxes, Law Enforcement & Crime, Congress & Legislation, Supreme Court & Judiciary, Housing & Community, Media & Press, Energy Independence]
# 4                                                                                                                      [National Security & Defense, Terrorism & Foreign Threats, Voting Rights, Patriotic Rhetoric, Law Enforcement & Crime, Congress & Legislation, Executive Power]

# %%
# Get counts of topics in theme data

# Explode and count
theme_counts = theme_clean_df['themes_list'].explode().value_counts()

all_themes_str = ", ".join(sorted(theme_clean_df['themes_list'].explode().unique()))

print(len(theme_counts))
print("\nList of themes:\n", all_themes_str)
print("\nCounts of themes:\n",theme_counts)
# Out:
# 29
#
# List of themes:
#  Civil Rights, Climate & Energy Policy, Congress & Legislation, Criminal Justice Reform, Economy & Taxes, Education, Election Integrity, Energy Independence, Executive Power, Government Overreach, Gun Policy, Healthcare, Housing & Community, Immigration, Iran & Nuclear Policy, Law Enforcement & Crime, Media & Press, National Security & Defense, Patriotic Rhetoric, Political Figures - Hillary Clinton, Political Figures - Obama, Political Figures - Trump, Reproductive Rights, Social Issues & Values, Social Safety Net & Entitlements, Supreme Court & Judiciary, Terrorism & Foreign Threats, Trump Name Calling, Voting Rights
#
# Counts of themes:
#  themes_list
# Congress & Legislation                 20159
# Media & Press                          17038
# Government Overreach                   14053
# Economy & Taxes                        13799
# Patriotic Rhetoric                     11527
# National Security & Defense            10920
# Energy Independence                    10896
# Healthcare                              9406
# Housing & Community                     8827
# Executive Power                         8772
# Social Safety Net & Entitlements        8418
# Social Issues & Values                  7758
# Education                               7721
# Law Enforcement & Crime                 7137
# Political Figures - Obama               6822
# Terrorism & Foreign Threats             5800
# Immigration                             2909
# Iran & Nuclear Policy                   2902
# Civil Rights                            2885
# Gun Policy                              2470
# Supreme Court & Judiciary               2433
# Voting Rights                           1622
# Climate & Energy Policy                  958
# Political Figures - Trump                693
# Political Figures - Hillary Clinton      637
# Criminal Justice Reform                  238
# Election Integrity                        75
# Reproductive Rights                       42
# Trump Name Calling                        35
# Name: count, dtype: int64

# %%
# Add body-text-parsing columns to dcinbox data including word count, fundraising term count, and ratio of fundraising terms found to total words

# Read in the list of fundraising terms and get their roots
terms_df = pd.read_csv("../data/dcinbox/fundraising_terms.csv")
term_roots = terms_df['term'].dropna().unique().tolist()

# Build a single regex pattern that matches any of the roots, case-insensitive
# Use word boundaries to avoid partial matches inside other words
# This was hard
term_pattern = re.compile(r'\b(?:' + '|'.join(re.escape(t) for t in term_roots) + r')\w*\b', flags=re.IGNORECASE)

# Convert dcinbox_df date field to a datetime (again??)
dcinbox_df['Date'] = pd.to_datetime(dcinbox_df['Date'])

# Compute total newsletters per politician
dcinbox_df["newsletter_count"] = 1
dcinbox_df["total_newsletters"] = dcinbox_df.groupby("Full Name")["newsletter_count"].transform("sum")

# Create word count column
dcinbox_df['body_word_count'] = dcinbox_df['Body'].str.split().str.len()

# Create column for fundraising term appearances
def count_terms(text):
    if pd.isna(text):
        return 0
    return len(term_pattern.findall(text))
dcinbox_df['fundraising_terms'] = dcinbox_df['Body'].apply(count_terms)

# Compute per-newsletter fundraising term ratio
dcinbox_df['fundraising_ratio'] = dcinbox_df.apply(
    lambda x: x['fundraising_terms'] / x['body_word_count'] if x['body_word_count'] > 0 else 0, axis=1
)

print("Rows in dcinbox_df:", len(dcinbox_df))
dcinbox_df.head()
# Out:
# Rows in dcinbox_df: 24224
#                                             Subject  \
# 0                                   Happy New Year!
# 1                                   Happy New Year!
# 2  OH-12 Update / A Look Back at the 114th Congress
# 3              The Leader's Daily Schedule - 1/3/17
# 4                         What I've Been Working On
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  Click here to open this e-mail in its own browser window Click here to open a plain text version of this email The Webster Wire Listening to Central Florida Dear Friends: From participating in local festivities in celebration of the season, to meeting with constituents, participating in food banks and toy drives, to welcoming family into town, it's been a great couple weeks in the district. The sight of a child's eyes lighting up at Christmas is joy that never grows old. _______________ Wreathes Across America ensures that no veteran who has passed is forgotten at Christmas and that their place of final rest is honored. It was a privilege to participate in their ceremony and wreathe laying at the Lone Oak Cemetery in Leesburg. We owe our military a debt we can never repay. _______________ Since their dedication just a few months ago, the Leesburg Salvation Army is doing great work in a short amount of time. I was honored to join them earlier this week to serve a hot breakfast to their community members and bell ringers. Thank you Lieutenant William Conley and volunteers for your service! _______________ If you want to be inspired and encouraged this season, spend some time with Don Diamont and his team that serves at the Leesburg Food Bank. With the help of local businesses such as Publix and residents, they put together food and gifts for those in need in the community. Thank you Don for allowing me to join you all in handing out baskets full of all the fixings for a delicious Christmas Dinner! _______________ Thank you to Ohio State students who teamed up with Habitat for Humanity during their winter break. I got to witness firsthand the results of their yardwork and see the vigor with which they tackled painting. It was a blessing to me to see their servant's heart and I know it touched the heart of the incoming homeowner. _______________ It has been an honor to serve the constituents of District 10 for the last six years. I am excited for what 2017 holds with the new administration and serving the constituents of District 11. Thank you and Happy New Year! Your servant, Daniel Webster Member of Congress Constituent Corner A constituent of Auburndale had received a letter from the VA almost two years ago stating he was entitled to retroactive funds, but he had never received the check. A request for an audit worksheet had been submitted in August 2015 to see what was bogging this down, but the constituent was still waiting. An inquiry was submitted on his behalf and in a follow up phone call, the length of the delay in processing this was discussed. Unfortunately, four months later, it was still pending and we were unable to get any estimate of a completion date. A second formal inquiry was submitted as it was not only way outside the
...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Click here to open this e-mail in its own browser window Click here to open a plain text version of this email News from Representative David Cicilline SERVING YOU | MEDIA CENTER | LEGISLATIVE WORK | OUR DISTRICT January 2, 2017 Dear Friend, Tomorrow, I will begin my fourth term representing you in the United States Congress. I'm honored by the trust you've placed in me to deliver results and get things done for our state. I wanted to take a moment to share some of the work we accomplished over the past two years, which I've compiled in the infographic below: Feel free to forward this email or share this infographic on social media with your friends and family. And for more information, you can visit my website at . I look forward to continuing our work together and hearing from you over the next two years. Warm Regards, David Cicilline Member of Congress CONNECT WITH ME Washington D.C. Office 2244 Rayburn HOB Washington, DC 20515 Phone: (202) 225-4911 Fax: (202) 225-3290 Pawtucket Office 1070 Main Street, Suite 300 Pawtucket, RI 02860 Phone: ...
#
#   Date of Birth Gender State  District Chamber Newsletter ID       Date  \
# 0       4/27/49      M    FL        10   House        136125 2017-01-02
# 1       11/1/53      M    CA        49   House        136126 2017-01-02
# 2      10/21/62      M    OH        12   House        136127 2017-01-02
# 3       1/26/65      M    CA        23   House        136128 2017-01-02
# 4       7/15/61      M    RI         1   House        136129 2017-01-02
#
#          Full Name Party  newsletter_count  total_newsletters  \
# 0   DANIEL WEBSTER     R                 1               96.0
# 1     DARRELL ISSA     R                 1                9.0
# 2   PATRICK TIBERI     R                 1               29.0
# 3   KEVIN MCCARTHY     R                 1              304.0
# 4  DAVID CICILLINE     D                 1              103.0
#
#    body_word_count  fundraising_terms  fundraising_ratio
# 0              690                  1           0.001449
# 1              435                  0           0.000000
# 2              620                  0           0.000000
# 3              179                  0           0.000000
# 4              192                  0           0.000000

# %%
# Filter dcinbox data to only keep house members & drop unneeded columns

# Keep only House members
dcinbox_filtered_df = dcinbox_df[dcinbox_df["Chamber"] == "House"]

# Drop unneeded columns
dcinbox_filtered_df = dcinbox_filtered_df.drop(
    columns=['Body', 'Nickname', 'Date of Birth', "First Name", "Last Name"],
    errors='ignore'
)

# Convert the ID field to an integer
dcinbox_filtered_df['Newsletter ID'] = pd.to_numeric(dcinbox_filtered_df['Newsletter ID'], errors='coerce').fillna(0).astype(int)

print("Records in dcinbox_filtered_df:", len(dcinbox_filtered_df))
# print("newsletter count:", dcinbox_filtered_df["newsletter_count"].sum())

dcinbox_filtered_df.head()
# Out:
# Records in dcinbox_filtered_df: 20582
#                                             Subject Gender State  District  \
# 0                                   Happy New Year!      M    FL        10
# 1                                   Happy New Year!      M    CA        49
# 2  OH-12 Update / A Look Back at the 114th Congress      M    OH        12
# 3              The Leader's Daily Schedule - 1/3/17      M    CA        23
# 4                         What I've Been Working On      M    RI         1
#
#   Chamber  Newsletter ID       Date        Full Name Party  newsletter_count  \
# 0   House         136125 2017-01-02   DANIEL WEBSTER     R                 1
# 1   House         136126 2017-01-02     DARRELL ISSA     R                 1
# 2   House         136127 2017-01-02   PATRICK TIBERI     R                 1
# 3   House         136128 2017-01-02   KEVIN MCCARTHY     R                 1
# 4   House         136129 2017-01-02  DAVID CICILLINE     D                 1
#
#    total_newsletters  body_word_count  fundraising_terms  fundraising_ratio
# 0               96.0              690                  1           0.001449
# 1                9.0              435                  0           0.000000
# 2               29.0              620                  0           0.000000
# 3              304.0              179                  0           0.000000
# 4              103.0              192                  0           0.000000

# %%
print(emotion_clean_df.columns)
print(dcinbox_filtered_df.columns)
# Out:
# Index(['date', 'newsletter_id', 'neutral_score', 'anger_score', 'joy_score',
#        'disgust_score', 'sadness_score', 'surprise_score', 'fear_score',
#        'full_name'],
#       dtype='object')
# Index(['Subject', 'Gender', 'State', 'District', 'Chamber', 'Newsletter ID',
#        'Date', 'Full Name', 'Party', 'newsletter_count', 'total_newsletters',
#        'body_word_count', 'fundraising_terms', 'fundraising_ratio'],
#       dtype='object')

# %%
# Join emotion data to dcinbox data

print("DCInbox before joining emotion data:", len(dcinbox_filtered_df))

# Make sure both dataframes have the same date format
dcinbox_filtered_df['Date'] = pd.to_datetime(dcinbox_filtered_df['Date'])
emotion_clean_df['date'] = pd.to_datetime(emotion_clean_df['date'])

dcinbox_emotion_df = dcinbox_filtered_df.merge(
    emotion_clean_df,
    left_on = ["Newsletter ID"],
    right_on = ["newsletter_id"],
    how = 'left'
)

# Drop the columns we don't need
dcinbox_emotion_df = dcinbox_emotion_df.drop(columns=["Subject", "full_name", "date", "newsletter_id"])

# print(dcinbox_filtered_df.columns)
# print(dcinbox_emotion_df.columns)

print("DCInbox after joining emotion data:", len(dcinbox_filtered_df))
dcinbox_emotion_df.head()
# Out:
# DCInbox before joining emotion data: 20582
# DCInbox after joining emotion data: 20582
#   Gender State  District Chamber  Newsletter ID       Date        Full Name  \
# 0      M    FL        10   House         136125 2017-01-02   DANIEL WEBSTER
# 1      M    CA        49   House         136126 2017-01-02     DARRELL ISSA
# 2      M    OH        12   House         136127 2017-01-02   PATRICK TIBERI
# 3      M    CA        23   House         136128 2017-01-02   KEVIN MCCARTHY
# 4      M    RI         1   House         136129 2017-01-02  DAVID CICILLINE
#
#   Party  newsletter_count  total_newsletters  body_word_count  \
# 0     R                 1               96.0              690
# 1     R                 1                9.0              435
# 2     R                 1               29.0              620
# 3     R                 1              304.0              179
# 4     D                 1              103.0              192
#
#    fundraising_terms  fundraising_ratio  neutral_score  anger_score  \
# 0                  1           0.001449       0.191091     0.007126
# 1                  0           0.000000       0.669645     0.004833
# 2                  0           0.000000       0.123493     0.003615
# 3                  0           0.000000       0.925763          NaN
# 4                  0           0.000000       0.408169     0.006270
#
#    joy_score  disgust_score  sadness_score  surprise_score  fear_score
# 0   0.717400            NaN       0.043490        0.036200         NaN
# 1   0.277138            NaN       0.012383        0.031704         NaN
# 2   0.794269            NaN       0.011713        0.063050         NaN
# 3   0.011104            NaN       0.012180        0.032708    0.009821
# 4   0.559634            NaN       0.004375        0.015404         NaN

# %%
dcinbox_emotion_df.columns
# Out:
# Index(['Gender', 'State', 'District', 'Chamber', 'Newsletter ID', 'Date',
#        'Full Name', 'Party', 'newsletter_count', 'total_newsletters',
#        'body_word_count', 'fundraising_terms', 'fundraising_ratio',
#        'neutral_score', 'anger_score', 'joy_score', 'disgust_score',
#        'sadness_score', 'surprise_score', 'fear_score'],
#       dtype='object')

# %%
theme_clean_df.columns
# Out:
# Index(['newsletter_id', 'matched_phrases', 'themes', 'themes_list'], dtype='object')

# %%
# Join theme data with the dcinbox data

dcinbox_theme_df = dcinbox_emotion_df.merge(
    theme_clean_df,
    left_on='Newsletter ID',
    right_on='newsletter_id',
    how='left'
)

# Drop the columns we don't need
dcinbox_theme_df = dcinbox_theme_df.drop(columns=["newsletter_id", "themes"])

dcinbox_theme_df.head()
# Out:
#   Gender State  District Chamber  Newsletter ID       Date        Full Name  \
# 0      M    FL        10   House         136125 2017-01-02   DANIEL WEBSTER
# 1      M    CA        49   House         136126 2017-01-02     DARRELL ISSA
# 2      M    OH        12   House         136127 2017-01-02   PATRICK TIBERI
# 3      M    CA        23   House         136128 2017-01-02   KEVIN MCCARTHY
# 4      M    RI         1   House         136129 2017-01-02  DAVID CICILLINE
#
#   Party  newsletter_count  total_newsletters  ...  fundraising_ratio  \
# 0     R                 1               96.0  ...           0.001449
# 1     R                 1                9.0  ...           0.000000
# 2     R                 1               29.0  ...           0.000000
# 3     R                 1              304.0  ...           0.000000
# 4     D                 1              103.0  ...           0.000000
#
#    neutral_score  anger_score  joy_score  disgust_score  sadness_score  \
# 0       0.191091     0.007126   0.717400            NaN       0.043490
# 1       0.669645     0.004833   0.277138            NaN       0.012383
# 2       0.123493     0.003615   0.794269            NaN       0.011713
# 3       0.925763          NaN   0.011104            NaN       0.012180
# 4       0.408169     0.006270   0.559634            NaN       0.004375
#
#    surprise_score  fear_score  \
# 0        0.036200         NaN
# 1        0.031704         NaN
# 2        0.063050         NaN
# 3        0.032708    0.009821
# 4        0.015404         NaN
#
#                                                                                                                                                                                                                                                                                                                        matched_phrases  \
# 0                                                                                                                                  ['obamacare', 'health', 'student', 'assistance', 'obama', 'congress', 'community', 'military', 'business', 'epa', 'bless', 'christmas', 'bureaucracy', 'federal government', 'government', 'press']
# 1                                                                                                                                                                                                       ['obama', 'president obama', 'bills', 'congress', 'law', 'national defense', 'defense', 'veterans', 'economy', 'epa', 'bless']
# 2  ['healthcare', 'obamacare', 'health', 'repeal', 'repeal and replace', 'border', 'trump', 'donald trump', 'obama', 'obama administration', 'legislation', 'house', 'congress', 'law', 'community', 'order', 'tax', 'tax relief', 'tax code', 'jobs', 'small business', 'business', 'epa', 'power', 'oversight', 'american', 'press']
# 3                                                                                                                                                                 ['legislation', 'house', 'congress', 'committee', 'vote', 'votes', 'majority', 'majority leader', 'sponsored', 'election', 'veterans', 'business', 'accountability']
# 4                                                                                                                                                                                                                                                                                              ['congress', 'states', 'media', 'news']
#
#                                                                                                                                                                                                                                                          themes_list
# 0  [National Security & Defense, Political Figures - Obama, Social Issues & Values, Healthcare, Social Safety Net & Entitlements, Education, Government Overreach, Economy & Taxes, Congress & Legislation, Housing & Community, Media & Press, Energy Independence]
# 1                                                                                                                     [National Security & Defense, Political Figures - Obama, Social Issues & Values, Economy & Taxes, Congress & Legislation, Energy Independence]
# 2                    [Political Figures - Obama, Healthcare, Patriotic Rhetoric, Law Enforcement & Crime, Economy & Taxes, Immigration, Congress & Legislation, Political Figures - Trump, Housing & Community, Media & Press, Executive Power, Energy Independence]
# 3                                                                                                                                                             [National Security & Defense, Voting Rights, Economy & Taxes, Congress & Legislation, Executive Power]
# 4                                                                                                                                                                                                      [Media & Press, Congress & Legislation, Government Overreach]
#
# [5 rows x 22 columns]

# %%
# Add T/F columns for presence of selected themes

# List of themes:
# Civil Rights, Climate & Energy Policy, Congress & Legislation, Criminal Justice Reform, Economy & Taxes, Education, 
# Election Integrity, Energy Independence, Executive Power, Government Overreach, Gun Policy, Healthcare, Housing & Community, 
# Immigration, Iran & Nuclear Policy, Law Enforcement & Crime, Media & Press, National Security & Defense, Patriotic Rhetoric, 
# Political Figures - Hillary Clinton, Political Figures - Obama, Political Figures - Trump, Reproductive Rights, 
# Social Issues & Values, Social Safety Net & Entitlements, Supreme Court & Judiciary, Terrorism & Foreign Threats, 
# Trump Name Calling, Voting Rights

# Get a list of the unique themes
unique_themes = (
    dcinbox_theme_df['themes_list']
    .explode()
    .dropna()
    .unique()
)
print(unique_themes)

# Create T/F columns for all the themes using a loop
for theme in unique_themes:
    colname = (
        "theme_" +
        theme.lower()
             .replace(" ", "_")
             .replace("&", "and")
    )
    dcinbox_theme_df[colname] = dcinbox_theme_df['themes_list'].apply(
        lambda lst, t=theme: t in lst if isinstance(lst, list) else False
    )

# Commented out adding T/F columns for themes one by one by hand
"""
dcinbox_theme_df['theme_immigration'] = dcinbox_theme_df['themes_list'].apply(
    lambda lst: 'Immigration' in lst if isinstance(lst, list) else False
)

dcinbox_theme_df['theme_natsec'] = dcinbox_theme_df['themes_list'].apply(
    lambda lst: 'National Security & Defense' in lst if isinstance(lst, list) else False
)

dcinbox_theme_df['theme_guns'] = dcinbox_theme_df['themes_list'].apply(
    lambda lst: 'Gun Policy' in lst if isinstance(lst, list) else False
)

dcinbox_theme_df['theme_energy'] = dcinbox_theme_df['themes_list'].apply(
    lambda lst: 'Energy Independence' in lst if isinstance(lst, list) else False
)
"""
# Out:
# ['National Security & Defense' 'Political Figures - Obama'
#  'Social Issues & Values' 'Healthcare' 'Social Safety Net & Entitlements'
#  'Education' 'Government Overreach' 'Economy & Taxes'
#  'Congress & Legislation' 'Housing & Community' 'Media & Press'
#  'Energy Independence' 'Patriotic Rhetoric' 'Law Enforcement & Crime'
#  'Immigration' 'Political Figures - Trump' 'Executive Power'
#  'Voting Rights' 'Terrorism & Foreign Threats' 'Supreme Court & Judiciary'
#  'Iran & Nuclear Policy' 'Gun Policy' 'Reproductive Rights'
#  'Climate & Energy Policy' 'Civil Rights'
#  'Political Figures - Hillary Clinton' 'Criminal Justice Reform'
#  'Election Integrity' 'Trump Name Calling']
# "\ndcinbox_theme_df['theme_immigration'] = dcinbox_theme_df['themes_list'].apply(\n    lambda lst: 'Immigration' in lst if isinstance(lst, list) else False\n)\n\ndcinbox_theme_df['theme_natsec'] = dcinbox_theme_df['themes_list'].apply(\n    lambda lst: 'National Security & Defense' in lst if isinstance(lst, list) else False\n)\n\ndcinbox_theme_df['theme_guns'] = dcinbox_theme_df['themes_list'].apply(\n    lambda lst: 'Gun Policy' in lst if isinstance(lst, list) else False\n)\n\ndcinbox_theme_df['theme_energy'] = dcinbox_theme_df['themes_list'].apply(\n    lambda lst: 'Energy Independence' in lst if isinstance(lst, list) else False\n)\n"

# %%
# QC of theme join column creation
test_theme = dcinbox_theme_df[dcinbox_theme_df["theme_trump_name_calling"] == True]
dcinbox_theme_df.head()

print(theme_raw_df.columns)
print(test_theme[["Newsletter ID", "Date"]])
# Out:
# Index(['first_name', 'last_name', 'party', 'email_id', 'subject',
#        'matched_phrases', 'themes', 'email'],
#       dtype='object')
#        Newsletter ID       Date
# 362           118576 2016-12-12
# 454           118682 2016-12-09
# 501           118743 2016-12-07
# 522           118767 2016-12-06
# 620           118917 2016-12-02
# 740           119025 2016-11-27
# 837           119159 2016-11-21
# 862           119172 2016-11-21
# 958           119281 2016-11-18
# 983           119316 2016-11-16
# 1123          119502 2016-11-10
# 1250          119655 2016-11-04
# 2163          120694 2016-09-30
# 2567          121190 2016-09-16
# 3223          121963 2016-08-21
# 4163          105554 2016-07-15
# 4358          105749 2016-07-09
# 4564          106002 2016-07-02
# 4573          106034 2016-07-01
# 4933          106465 2016-06-20
# 5472          107123 2016-06-02
# 6020          107780 2016-05-16
# 6643          108516 2016-04-27
# 7985          111181 2016-03-12
# 8325          111593 2016-03-01
# 9559          112003 2016-01-19
# 9732          112205 2016-01-13
# 9752          112229 2016-01-12
# 9868          112354 2016-01-09
# 13320         116397 2015-09-14
# 13508         116613 2015-09-09
# 13519         116626 2015-09-09
# 13763         116904 2015-08-30
# 16455          96231 2015-05-31
# 17111          97005 2015-05-09

# %%
pd.set_option('display.max_colwidth', None)

test = theme_raw_df[theme_raw_df["email_id"] == 105554]
test
# Out:
#       first_name last_name       party  email_id  \
# 16352       Evan   Jenkins  Republican  105554.0
#
#                                                          subject  \
# 16352  Rep. Evan Jenkins: Opioid bill headed to president's desk
#
#                                                                                                               matched_phrases  \
# 16352  ['health', 'benefit', 'assistance', 'legislation', 'the bill', 'congress', 'law', 'isis', 'accountable', 'pocahontas']
#
#                                                                                                                                                      themes  \
# 16352  ['Terrorism & Foreign Threats', 'Healthcare', 'Social Safety Net & Entitlements', 'Trump Name Calling', 'Congress & Legislation', 'Executive Power']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       email
# 16352  View this email in your browser ( I joined Speaker Paul Ryan for the bill signing of the Comprehensive Addiction and Recovery Act, which is now on its way to the president's desk. ** Working together to make a difference in the drug crisis. ------------------------------------------------------------ This week, Congress helped to turn the tide in the fight against our nation's drug epidemic. Our bipartisan legislation addressing the opioid crisis, the Comprehensive Addiction and Recovery Act, is on its way to the president to be signed into law. And this good bill includes my legislation, the Nurturing and Supporting Healthy Babies Act, which will improve care for babies born with neonatal abstinence syndrome, drug exposure during pregnancy. These babies need specialized care and treatment to help them heal and ease the symptoms of withdrawal after birth, and my bill will help improve our knowledge of how to treat them. By setting aside partisan differences and working together, we are sending the president legislation that will make a true difference in the lives of the most innocent victims of the drug crisis. Holding FEMA accountable As your voice in Congress, I'm committed to making sure our neighbors and communities get the federal support needed to recover and rebuild from our recent floods. That includes helping you navigate the application process and holding agencies accountable if they fail to deliver. If you need help with FEMA or are unhappy with the answers you have received, I want to help you. Please call my Beckley office at (304) 250-6177, my Huntington office at (304) 522-2201, or email me at _public@ . If you need help from FEMA but cannot travel to a mobile disaster recovery center, please call and let me know. I can have a FEMA team sent to meet you at your residence. We have a long road to recovery ahead, and I will do everything possible to fight for you. Sincerely, Evan Jenkins Member of Congress ** Flood response mobile office hours ------------------------------------------------------------ My staff will be holding special flood assistance mobile office hours next week in communities affected by the recent flooding. Members of my staff will be available to meet with residents affected by flooding and help them with federal assistance programs. Monday, July 18 11 a.m. to 12:30 p.m. White Sulphur Springs City Hall 34 W. Main St. White Sulphur Springs, . 24986 Wednesday, July 20 10 a.m. to 11:30 a.m. Rainelle City Hall 201 Kanawha Ave. Rainelle, . 25962 Thursday, July 21 2:30-3:30 p.m. Pocahontas County Library 500 Eighth St. Marlinton, . 24954 ** Mobile office hours ------------------------------------------------------------ My staff will be holding mobile office hours in Wayne, Williamson and Oceana next week. These mobile office hours offer residents the chance to meet with my staff about federal benefits and programs without having to travel to one of my district offices. Constituents are encouraged to bring along documents they have received from federal agencies related to their issues. Monday, July 18 11 a.m. to noon James Booten Memorial Apartments Old Wayne Grade School 11081 Route 152 Wayne, . 25570 Tuesday, July 19 2:30-3:30 p.m. Williamson Public Library 101 Logan St. Williamson, . 25661 Wednesday, July 20 12:30-1:30 p.m. Oceana City Hall 1285 Cook Parkway Oceana, . 24870 ============================================================ ** ( ** ( ** ( ** ( ) BLUEFIELD 601 Federal St. Suite 1003 Bluefield, WV 24701 (304) 325-6800 BECKLEY 223 Prince St. Beckley, WV 25801 (304) 250-6177 HUNTINGTON 845 Fifth Ave. Suite 314 Huntington, WV 25701 (304) 522-2201 WASHINGTON, D.C. 502 Cannon HOB Washington, DC 20515 (202) 225-3452 Want to change how you receive these emails? You can ** update your preferences ( or **   from this list (

# %%
# Pre-joining QC

# Dcinbox file with counts of newsletters by day
# print(len(dcinbox_emotion_df))
print(len(dcinbox_theme_df))

# file with politicians matched between dcinbox and FEC data
print(len(matched_pols_df))

# Summary FEC file of candidates and contributions by day
print(len(cand_contribs_df))
# Out:
# 20582
# 396
# 94666

# %%
print(dcinbox_theme_df.columns)
print(matched_pols_df.columns)
# Out:
# Index(['Gender', 'State', 'District', 'Chamber', 'Newsletter ID', 'Date',
#        'Full Name', 'Party', 'newsletter_count', 'total_newsletters',
#        'body_word_count', 'fundraising_terms', 'fundraising_ratio',
#        'neutral_score', 'anger_score', 'joy_score', 'disgust_score',
#        'sadness_score', 'surprise_score', 'fear_score', 'matched_phrases',
#        'themes_list', 'theme_national_security_and_defense',
#        'theme_political_figures_-_obama', 'theme_social_issues_and_values',
#        'theme_healthcare', 'theme_social_safety_net_and_entitlements',
#        'theme_education', 'theme_government_overreach',
#        'theme_economy_and_taxes', 'theme_congress_and_legislation',
#        'theme_housing_and_community', 'theme_media_and_press',
#        'theme_energy_independence', 'theme_patriotic_rhetoric',
#        'theme_law_enforcement_and_crime', 'theme_immigration',
#        'theme_political_figures_-_trump', 'theme_executive_power',
#        'theme_voting_rights', 'theme_terrorism_and_foreign_threats',
#        'theme_supreme_court_and_judiciary', 'theme_iran_and_nuclear_policy',
#        'theme_gun_policy', 'theme_reproductive_rights',
#        'theme_climate_and_energy_policy', 'theme_civil_rights',
#        'theme_political_figures_-_hillary_clinton',
#        'theme_criminal_justice_reform', 'theme_election_integrity',
#        'theme_trump_name_calling'],
#       dtype='object')
# Index(['target_id', 'dcinbox_name', 'fec_cid', 'fec_name', 'fec_party',
#        'fec_state', 'fec_district', 'fec_cycle', 'append_attribute2',
#        'append_attribute3', 'similarity_score', 'matched_scorer'],
#       dtype='object')

# %%
# Join merged DC Inbox and matched politicians data into a new data frame (left join)

dcinbox_merged_df = dcinbox_theme_df.merge(
    matched_pols_df,
    left_on = ["Full Name"], # , "State", "District", "Party"],
    right_on = ["dcinbox_name"], # "fec_state", "fec_district", "fec_party"],
    how = 'left'
)

# Drop the columns we don't need
dcinbox_merged_df = dcinbox_merged_df.drop(columns=['fec_state', 'fec_district', 'fec_party', "target_id", "append_attribute2", "append_attribute3",
                                                "matched_scorer", "dcinbox_name", 'Chamber', "similarity_score", "fec_cycle"])

# Field cleanup & type correction
# dcinbox_merged_df["Date"] == "2020-02-01"
# print(summ_df['fec_cycle'] = dc_inbox_sum_df['fec_cycle'].fillna(0).astype(int)
# dc_inbox_sum_df['similarity_score'] = dc_inbox_sum_df['similarity_score'].fillna(0).astype(int)
dcinbox_merged_df['Date'] = pd.to_datetime(dcinbox_merged_df['Date'])
dcinbox_merged_df = dcinbox_merged_df.rename(columns={'Subject': 'subject'})

# Rename columns so they won't clash with the FEC data file
dcinbox_merged_df = dcinbox_merged_df.rename(columns={
    "Full Name": "dc_name",
    "Date": "dc_date",
    "Congress": "dc_congress",
    "Gender": "dc_gender",
    "State": "dc_state",
    "District": "dc_district",
    "Chamber": "dc_chamber",
    "Party": "dc_party",
    "Newsletter ID": "newsletter_id"  
})

print(len(dcinbox_merged_df))
dcinbox_merged_df.head()
# dc_inbox_sum_df.info()
# Out:
# 20582
#   dc_gender dc_state  dc_district  newsletter_id    dc_date          dc_name  \
# 0         M       FL           10         136125 2017-01-02   DANIEL WEBSTER
# 1         M       CA           49         136126 2017-01-02     DARRELL ISSA
# 2         M       OH           12         136127 2017-01-02   PATRICK TIBERI
# 3         M       CA           23         136128 2017-01-02   KEVIN MCCARTHY
# 4         M       RI            1         136129 2017-01-02  DAVID CICILLINE
#
#   dc_party  newsletter_count  total_newsletters  body_word_count  ...  \
# 0        R                 1               96.0              690  ...
# 1        R                 1                9.0              435  ...
# 2        R                 1               29.0              620  ...
# 3        R                 1              304.0              179  ...
# 4        D                 1              103.0              192  ...
#
#    theme_gun_policy  theme_reproductive_rights  \
# 0             False                      False
# 1             False                      False
# 2             False                      False
# 3             False                      False
# 4             False                      False
#
#    theme_climate_and_energy_policy  theme_civil_rights  \
# 0                            False               False
# 1                            False               False
# 2                            False               False
# 3                            False               False
# 4                            False               False
#
#    theme_political_figures_-_hillary_clinton  theme_criminal_justice_reform  \
# 0                                      False                          False
# 1                                      False                          False
# 2                                      False                          False
# 3                                      False                          False
# 4                                      False                          False
#
#    theme_election_integrity  theme_trump_name_calling    fec_cid  \
# 0                     False                     False  N00026335
# 1                     False                     False  N00007017
# 2                     False                     False  N00009699
# 3                     False                     False  N00028152
# 4                     False                     False  N00032019
#
#           fec_name
# 0   DANIEL WEBSTER
# 1     DARRELL ISSA
# 2       PAT TIBERI
# 3   KEVIN MCCARTHY
# 4  DAVID CICILLINE
#
# [5 rows x 52 columns]

# %%
# Join summarized FEC and DC Inbox into a new data frame (left join) by day & politician,
# For use in computing rolling window contribution amount & count columns

print(len(dcinbox_merged_df))
print(len(cand_contribs_df))

# Date field type corrections
dcinbox_merged_df['dc_date'] = pd.to_datetime(dcinbox_merged_df['dc_date'])
cand_contribs_df['contrib_date'] = pd.to_datetime(cand_contribs_df['contrib_date'])

window_col_join_df = cand_contribs_df.merge(
# joined_all_df = test_dcinbox_df.merge(
    # dc_inbox_sum_df,
    dcinbox_merged_df.drop(columns=["fec_name", "dc_party", "dc_district",
                                  "dc_name", "newsletter_count", "body_word_count",
                                  "dc_state", "dc_gender"]),
    left_on = ['fec_cid', "contrib_date"],
    right_on = ['fec_cid', "dc_date"],
    how = 'left'
)

print(len(window_col_join_df))
window_col_join_df.head()
# dc_inbox_sum_df.info()
# Out:
# 20582
# 94666
# 94792
#    fec_cycle    fec_cid     fec_name fec_state  fec_district fec_party  \
# 0       2016  N00030768  MARTHA ROBY        AL             2         R
# 1       2016  N00030768  MARTHA ROBY        AL             2         R
# 2       2016  N00030768  MARTHA ROBY        AL             2         R
# 3       2016  N00030768  MARTHA ROBY        AL             2         R
# 4       2016  N00030768  MARTHA ROBY        AL             2         R
#
#   contrib_date  contrib_count  contrib_amount month_start  ...  \
# 0   2015-02-11              1             250  2015-02-01  ...
# 1   2015-02-18              2            1478  2015-02-01  ...
# 2   2015-02-26              1            2700  2015-02-01  ...
# 3   2015-03-02             26           40350  2015-03-01  ...
# 4   2015-03-11              1            1000  2015-03-01  ...
#
#    theme_supreme_court_and_judiciary  theme_iran_and_nuclear_policy  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#    theme_gun_policy theme_reproductive_rights  \
# 0               NaN                       NaN
# 1               NaN                       NaN
# 2               NaN                       NaN
# 3               NaN                       NaN
# 4               NaN                       NaN
#
#    theme_climate_and_energy_policy  theme_civil_rights  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
#
#    theme_political_figures_-_hillary_clinton  theme_criminal_justice_reform  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#    theme_election_integrity  theme_trump_name_calling
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
# [5 rows x 55 columns]

# %%
# Add a rolling window of a set number of days after the initial newsletter date to the joined FEC/DC Inbox data frame

# Set window days
input_window_days = 2

# Use a small test set
# window_col_df = window_col_join_df[window_col_join_df["fec_name"].str.contains("PELOSI")].copy()
# window_col_df = window_col_df[window_col_df["contrib_date"] >= "2019-11-19"].copy()

window_col_df = window_col_join_df.copy()

# Make sure date columns are datetime
window_col_df["contrib_date"] = pd.to_datetime(window_col_df["contrib_date"], errors = "coerce")
window_col_df["dc_date"] = pd.to_datetime(window_col_df["dc_date"], errors = "coerce")

# Fill NaNs in contrib columns to avoid issues during summing
window_col_df["contrib_count"] = window_col_df["contrib_count"].fillna(0).astype(int)
window_col_df["contrib_amount"] = window_col_df["contrib_amount"].fillna(0).astype(int)

# Define the group columns (unique identifiers for rolling sums)
group_cols = ["fec_name", "fec_state", "fec_district", "fec_party"]
window_col_df[group_cols] = window_col_df[group_cols].fillna("NA")

# Sort by group and date
window_col_df = window_col_df.sort_values(by = group_cols + ["contrib_date"])

# Define a general rolling window function
def add_forward_rolling_sum(df, value_cols, window_days = input_window_days):
    """
    args: df: this df is blah


    output: a new dataframe with columns
    """
    # value_cols should be a list, e.g. ["contrib_count", "contrib_amount"]
    days_col = "window_days"
    df[days_col] = 0  # initialize shared days column

    for value_col in value_cols:
        new_col = f"window_{value_col}"
        df[new_col] = 0

    for name, g in df.groupby(group_cols, sort=False):
        g = g.sort_values("contrib_date")
        contrib_dates = g["contrib_date"].reset_index(drop=True)
        dates = g["dc_date"].reset_index(drop=True)
        results = {val: np.zeros(len(g), dtype=int) for val in value_cols}
        actual_days = np.zeros(len(g), dtype=int)

        for i, current_date in enumerate(dates):

            if pd.isna(current_date):
                actual_days[i] = 0
                for value_col in value_cols:
                    results[value_col][i] = 0
                continue     

            # Default window end
            window_end = current_date + pd.Timedelta(days=window_days)

            # Include all dates within window initially
            mask = (contrib_dates >= current_date) & (contrib_dates <= window_end)

            # Stop before first non-NaT dc_date if found
            next_reset_idx = np.where((dates > current_date) & pd.notna(dates))[0]
            if len(next_reset_idx) > 0:
                first_reset_date = dates[next_reset_idx[0]]
                mask = mask & (contrib_dates < first_reset_date)
                window_end = min(window_end, first_reset_date - pd.Timedelta(days=1))

            # Store actual number of days used
            actual_days[i] = (window_end - current_date).days + 1

            # Compute rolling sums for all specified value columns
            for value_col in value_cols:
                values = g[value_col].fillna(0).astype(int).reset_index(drop=True)
                results[value_col][i] = int(values[mask].sum())

        # Write results back to df
        for value_col in value_cols:
            new_col = f"window_{value_col}"
            df.loc[g.index, new_col] = results[value_col]
        df.loc[g.index, days_col] = actual_days

    return df


# Compute rolling sums for count and amount
window_col_df = add_forward_rolling_sum(
    window_col_df,
    value_cols=["contrib_count", "contrib_amount"],
    window_days = input_window_days
)

# Check results
# joined_all_window_df.head()[["dc_date", "dc_name", "contrib_count", "window_contrib_count", 
#                              "contrib_amount", "window_contrib_amount"]]
window_col_df.head()

# window_col_nonzero_df = window_col_df[window_col_df["window_contrib_amount"] > 0]
# window_col_nonzero_df.head()
# Out:
#       fec_cycle    fec_cid        fec_name fec_state  fec_district fec_party  \
# 5712       2016  N00030667  ADAM KINZINGER        IL            16         R
# 5713       2016  N00030667  ADAM KINZINGER        IL            16         R
# 5714       2016  N00030667  ADAM KINZINGER        IL            16         R
# 5715       2016  N00030667  ADAM KINZINGER        IL            16         R
# 5716       2016  N00030667  ADAM KINZINGER        IL            16         R
#
#      contrib_date  contrib_count  contrib_amount month_start  ...  \
# 5712   2015-01-22              1             500  2015-01-01  ...
# 5713   2015-02-03              1             250  2015-02-01  ...
# 5714   2015-02-05              1             500  2015-02-01  ...
# 5715   2015-02-09              1            1000  2015-02-01  ...
# 5716   2015-02-12              9            3400  2015-02-01  ...
#
#       theme_reproductive_rights  theme_climate_and_energy_policy  \
# 5712                        NaN                              NaN
# 5713                        NaN                              NaN
# 5714                        NaN                              NaN
# 5715                        NaN                              NaN
# 5716                        NaN                              NaN
#
#       theme_civil_rights theme_political_figures_-_hillary_clinton  \
# 5712                 NaN                                       NaN
# 5713                 NaN                                       NaN
# 5714                 NaN                                       NaN
# 5715                 NaN                                       NaN
# 5716                 NaN                                       NaN
#
#       theme_criminal_justice_reform  theme_election_integrity  \
# 5712                            NaN                       NaN
# 5713                            NaN                       NaN
# 5714                            NaN                       NaN
# 5715                            NaN                       NaN
# 5716                            NaN                       NaN
#
#       theme_trump_name_calling  window_days  window_contrib_count  \
# 5712                       NaN            0                     0
# 5713                       NaN            0                     0
# 5714                       NaN            0                     0
# 5715                       NaN            0                     0
# 5716                       NaN            0                     0
#
#       window_contrib_amount
# 5712                      0
# 5713                      0
# 5714                      0
# 5715                      0
# 5716                      0
#
# [5 rows x 58 columns]

# %%
# QC for joining

# test_date = "2015-02-09"
# test_name = "KINZINGER"
test_date = "2016-02-07"
test_name = "SCHIFF"

dcinbox_merged_df['dc_date'] = pd.to_datetime(dcinbox_merged_df['dc_date'])
test_dcinbox_df = dcinbox_merged_df[dcinbox_merged_df["dc_date"] == test_date]
test_dcinbox_df = test_dcinbox_df[test_dcinbox_df["dc_name"].str.contains(test_name)]

cand_contribs_df['contrib_date'] = pd.to_datetime(cand_contribs_df['contrib_date'])
test_fec_df = cand_contribs_df[cand_contribs_df["contrib_date"] == test_date]
test_fec_df = test_fec_df[test_fec_df["fec_name"].str.contains(test_name)]

print(len(test_dcinbox_df))
print(len(test_fec_df))
# test_dcinbox_df.head()
test_fec_df.head()
# Out:
# 0
# 1
#       fec_cycle    fec_cid     fec_name fec_state  fec_district fec_party  \
# 2687       2016  N00009585  ADAM SCHIFF        CA            28         D
#
#      contrib_date  contrib_count  contrib_amount month_start  \
# 2687   2016-02-07              5            6650  2016-02-01
#
#       avg_daily_contrib_count_per_month  avg_daily_contrib_amount_per_month
# 2687                           0.206897                          237.931034

# %%
print(window_col_df.columns)
print(dcinbox_merged_df.columns)
# Out:
# Index(['fec_cycle', 'fec_cid', 'fec_name', 'fec_state', 'fec_district',
#        'fec_party', 'contrib_date', 'contrib_count', 'contrib_amount',
#        'month_start', 'avg_daily_contrib_count_per_month',
#        'avg_daily_contrib_amount_per_month', 'newsletter_id', 'dc_date',
#        'total_newsletters', 'fundraising_terms', 'fundraising_ratio',
#        'neutral_score', 'anger_score', 'joy_score', 'disgust_score',
#        'sadness_score', 'surprise_score', 'fear_score', 'matched_phrases',
#        'themes_list', 'theme_national_security_and_defense',
#        'theme_political_figures_-_obama', 'theme_social_issues_and_values',
#        'theme_healthcare', 'theme_social_safety_net_and_entitlements',
#        'theme_education', 'theme_government_overreach',
#        'theme_economy_and_taxes', 'theme_congress_and_legislation',
#        'theme_housing_and_community', 'theme_media_and_press',
#        'theme_energy_independence', 'theme_patriotic_rhetoric',
#        'theme_law_enforcement_and_crime', 'theme_immigration',
#        'theme_political_figures_-_trump', 'theme_executive_power',
#        'theme_voting_rights', 'theme_terrorism_and_foreign_threats',
#        'theme_supreme_court_and_judiciary', 'theme_iran_and_nuclear_policy',
#        'theme_gun_policy', 'theme_reproductive_rights',
#        'theme_climate_and_energy_policy', 'theme_civil_rights',
#        'theme_political_figures_-_hillary_clinton',
#        'theme_criminal_justice_reform', 'theme_election_integrity',
#        'theme_trump_name_calling', 'window_days', 'window_contrib_count',
#        'window_contrib_amount'],
#       dtype='object')
# Index(['dc_gender', 'dc_state', 'dc_district', 'newsletter_id', 'dc_date',
#        'dc_name', 'dc_party', 'newsletter_count', 'total_newsletters',
#        'body_word_count', 'fundraising_terms', 'fundraising_ratio',
#        'neutral_score', 'anger_score', 'joy_score', 'disgust_score',
#        'sadness_score', 'surprise_score', 'fear_score', 'matched_phrases',
#        'themes_list', 'theme_national_security_and_defense',
#        'theme_political_figures_-_obama', 'theme_social_issues_and_values',
#        'theme_healthcare', 'theme_social_safety_net_and_entitlements',
#        'theme_education', 'theme_government_overreach',
#        'theme_economy_and_taxes', 'theme_congress_and_legislation',
#        'theme_housing_and_community', 'theme_media_and_press',
#        'theme_energy_independence', 'theme_patriotic_rhetoric',
#        'theme_law_enforcement_and_crime', 'theme_immigration',
#        'theme_political_figures_-_trump', 'theme_executive_power',
#        'theme_voting_rights', 'theme_terrorism_and_foreign_threats',
#        'theme_supreme_court_and_judiciary', 'theme_iran_and_nuclear_policy',
#        'theme_gun_policy', 'theme_reproductive_rights',
#        'theme_climate_and_energy_policy', 'theme_civil_rights',
#        'theme_political_figures_-_hillary_clinton',
#        'theme_criminal_justice_reform', 'theme_election_integrity',
#        'theme_trump_name_calling', 'fec_cid', 'fec_name'],
#       dtype='object')

# %%
# Join merged DC Inbox and window-column FEC into a new data frame (left join) by day & politician

print("window_col_df: ", len(window_col_df))
print("dcinbox_merged_df: ", len(dcinbox_merged_df))

# Build a dynamic list of all columns starting with "theme_"
score_cols = [c for c in window_col_df.columns if c.endswith("_score")]
theme_cols = [c for c in window_col_df.columns if c.startswith("theme_")]

# Merge by politician and date
joined_all_df = dcinbox_merged_df.merge(
    window_col_df.drop(
        columns = [
            'fec_cycle', 'fec_name', 'fec_party', 'fec_state', 'fec_district',
            'dc_date', 'fundraising_terms', 'total_newsletters',
            'fundraising_ratio', 'newsletter_id', 'themes_list', 'matched_phrases'
        ] + theme_cols + score_cols
    ),
    left_on=['fec_cid', 'dc_date'],
    right_on=['fec_cid', 'contrib_date'],
    how='left'
)

print("joined_all_df: ", len(joined_all_df))

# Add score columns normalizing by this month's average daily performance
joined_all_df["window_fundraising_count_score"] = (
    (joined_all_df["window_contrib_count"] / joined_all_df["window_days"]) /
    joined_all_df["avg_daily_contrib_count_per_month"]
)
joined_all_df["window_fundraising_amount_score"] = (
    (joined_all_df["window_contrib_amount"] / joined_all_df["window_days"]) /
    joined_all_df["avg_daily_contrib_amount_per_month"]
)

# Fill missing values for quantitative columns & format them
num_cols_int = [
    "window_days", "contrib_count", "avg_daily_contrib_count",
    "window_contrib_count", "avg_daily_contrib_count_per_month"
]
num_cols_float = [
    "contrib_amount", "avg_daily_contrib_amount", "window_contrib_amount",
    "window_fundraising_count_score", "window_fundraising_amount_score",
    "avg_daily_contrib_amount_per_month"
]

# Fill NAs
for col in num_cols_int:
    if col in joined_all_df.columns:
        joined_all_df[col] = joined_all_df[col].fillna(0).astype(int)
for col in num_cols_float:
    if col in joined_all_df.columns:
        joined_all_df[col] = joined_all_df[col].fillna(0).astype(float).map("{:.2f}".format)

# print(dc_inbox_sum_df.columns)
# print(joined_all_df.columns)
joined_all_df.head()
# print(window_col_df.columns)
# Out:
# window_col_df:  94792
# dcinbox_merged_df:  20582
# joined_all_df:  20889
#   dc_gender dc_state  dc_district  newsletter_id    dc_date          dc_name  \
# 0         M       FL           10         136125 2017-01-02   DANIEL WEBSTER
# 1         M       CA           49         136126 2017-01-02     DARRELL ISSA
# 2         M       OH           12         136127 2017-01-02   PATRICK TIBERI
# 3         M       CA           23         136128 2017-01-02   KEVIN MCCARTHY
# 4         M       RI            1         136129 2017-01-02  DAVID CICILLINE
#
#   dc_party  newsletter_count  total_newsletters  body_word_count  ...  \
# 0        R                 1               96.0              690  ...
# 1        R                 1                9.0              435  ...
# 2        R                 1               29.0              620  ...
# 3        R                 1              304.0              179  ...
# 4        D                 1              103.0              192  ...
#
#    contrib_count  contrib_amount  month_start  \
# 0              0            0.00          NaT
# 1              0            0.00          NaT
# 2              0            0.00          NaT
# 3              0            0.00          NaT
# 4              0            0.00          NaT
#
#    avg_daily_contrib_count_per_month  avg_daily_contrib_amount_per_month  \
# 0                                  0                                0.00
# 1                                  0                                0.00
# 2                                  0                                0.00
# 3                                  0                                0.00
# 4                                  0                                0.00
#
#    window_days  window_contrib_count  window_contrib_amount  \
# 0            0                     0                   0.00
# 1            0                     0                   0.00
# 2            0                     0                   0.00
# 3            0                     0                   0.00
# 4            0                     0                   0.00
#
#    window_fundraising_count_score window_fundraising_amount_score
# 0                            0.00                            0.00
# 1                            0.00                            0.00
# 2                            0.00                            0.00
# 3                            0.00                            0.00
# 4                            0.00                            0.00
#
# [5 rows x 63 columns]

# %%
joined_all_df.columns
# Out:
# Index(['dc_gender', 'dc_state', 'dc_district', 'newsletter_id', 'dc_date',
#        'dc_name', 'dc_party', 'newsletter_count', 'total_newsletters',
#        'body_word_count', 'fundraising_terms', 'fundraising_ratio',
#        'neutral_score', 'anger_score', 'joy_score', 'disgust_score',
#        'sadness_score', 'surprise_score', 'fear_score', 'matched_phrases',
#        'themes_list', 'theme_national_security_and_defense',
#        'theme_political_figures_-_obama', 'theme_social_issues_and_values',
#        'theme_healthcare', 'theme_social_safety_net_and_entitlements',
#        'theme_education', 'theme_government_overreach',
#        'theme_economy_and_taxes', 'theme_congress_and_legislation',
#        'theme_housing_and_community', 'theme_media_and_press',
#        'theme_energy_independence', 'theme_patriotic_rhetoric',
#        'theme_law_enforcement_and_crime', 'theme_immigration',
#        'theme_political_figures_-_trump', 'theme_executive_power',
#        'theme_voting_rights', 'theme_terrorism_and_foreign_threats',
#        'theme_supreme_court_and_judiciary', 'theme_iran_and_nuclear_policy',
#        'theme_gun_policy', 'theme_reproductive_rights',
#        'theme_climate_and_energy_policy', 'theme_civil_rights',
#        'theme_political_figures_-_hillary_clinton',
#        'theme_criminal_justice_reform', 'theme_election_integrity',
#        'theme_trump_name_calling', 'fec_cid', 'fec_name', 'contrib_date',
#        'contrib_count', 'contrib_amount', 'month_start',
#        'avg_daily_contrib_count_per_month',
#        'avg_daily_contrib_amount_per_month', 'window_days',
#        'window_contrib_count', 'window_contrib_amount',
#        'window_fundraising_count_score', 'window_fundraising_amount_score'],
#       dtype='object')

# %%
# QC to find duplicates in joined data

joined_dupes = joined_all_df[joined_all_df.duplicated(subset=["newsletter_id", "dc_name", "dc_date"], keep=False)]
print("Number of duplicates in joined_all_df:", len(joined_dupes))
# print(joined_dupes)
# Out:
# Number of duplicates in joined_all_df: 578

# %%
# Drop any duplicate records from joined data

joined_all_df = joined_all_df.drop_duplicates(subset=['newsletter_id'])

dc_dupes = joined_all_df[joined_all_df.duplicated(subset=["newsletter_id", "dc_name", "dc_date"], keep=False)]
print("Number of duplicates in joined_all_df after dropping duplicates on id/name/date:", len(dc_dupes))

print("Length of joined_all_df:", len(joined_all_df))
# Out:
# Number of duplicates in joined_all_df after dropping duplicates on id/name/date: 0
# Length of joined_all_df: 20582

# %%
# QC for specific Congresspeople

joined_all_qc_df = joined_all_df[joined_all_df["dc_name"] == "ADAM KINZINGER"]
joined_all_qc_df = joined_all_qc_df[
    pd.to_numeric(joined_all_qc_df["window_fundraising_amount_score"], errors="coerce") > 0
]

joined_all_qc_df.head()
# Out:
#       dc_gender dc_state  dc_district  newsletter_id    dc_date  \
# 16470         M       IL           16          95953 2015-06-08
# 17283         M       IL           16          96881 2015-05-13
#
#               dc_name dc_party  newsletter_count  total_newsletters  \
# 16470  ADAM KINZINGER        R                 1                4.0
# 17283  ADAM KINZINGER        R                 1                4.0
#
#        body_word_count  ...  contrib_count  contrib_amount  month_start  \
# 16470              961  ...              4         2269.00   2015-06-01
# 17283              850  ...              8         9760.00   2015-05-01
#
#        avg_daily_contrib_count_per_month  avg_daily_contrib_amount_per_month  \
# 16470                                  1                             1525.63
# 17283                                  1                             1714.84
#
#        window_days  window_contrib_count  window_contrib_amount  \
# 16470            3                     8                7469.00
# 17283            3                    12               13260.00
#
#        window_fundraising_count_score window_fundraising_amount_score
# 16470                            1.86                            1.63
# 17283                            2.25                            2.58
#
# [2 rows x 63 columns]

# %%
# Output the final joined file to a CSV file for using for figures

joined_all_df.to_csv(
    "../data/matched/joined_all_2016.csv",
    index=False  # no row numbers
    # encoding="latin1"
)

# %%
# Parameter sweep to test monthly average count & contribution scores for different window lengths
test_window_days = range(0, 6)
value_cols = ["contrib_count", "contrib_amount"]
window_cols = [f"window_{v}" for v in value_cols]
test_results = []

for days in test_window_days:
    # --- 1. Compute rolling window columns
    temp_df = add_forward_rolling_sum(
        window_col_df.copy(),
        value_cols=value_cols,
        window_days=days
    )

    # --- 2. Merge into DC Inbox summary (this produces "detail" rows)
    joined_all_df = dcinbox_merged_df.merge(
        temp_df.drop(
            columns=[
                "fec_cycle", "fec_name", "fec_party", "fec_state",
                "fec_district", "dc_date", "fundraising_terms",
                "total_newsletters", "fundraising_ratio"
            ],
            errors="ignore"
        ),
        left_on=["fec_cid", "dc_date"],
        right_on=["fec_cid", "contrib_date"],
        how="left"
    )

    # --- 3. Ensure no division by zero
    joined_all_df["window_days"] = joined_all_df["window_days"].replace(0, np.nan)

    # --- 4. Compute month_daily_*_score columns on the detailed rows
    joined_all_df["window_fundraising_count_score"] = (
        (joined_all_df["window_contrib_count"] / joined_all_df["window_days"]) /
        joined_all_df["avg_daily_contrib_count_per_month"]
    )
    joined_all_df["window_fundraising_amount_score"] = (
        (joined_all_df["window_contrib_amount"] / joined_all_df["window_days"]) /
        joined_all_df["avg_daily_contrib_amount_per_month"]
    )

    # --- 5. Clean up invalid values
    joined_all_df[["window_fundraising_count_score", "window_fundraising_amount_score"]] = (
        joined_all_df[["window_fundraising_count_score", "window_fundraising_amount_score"]]
        .replace([np.inf, -np.inf], np.nan)
        .fillna(0)
    )

    # --- 6. Ensure date and numeric fields are usable
    joined_all_df["dc_date"] = pd.to_datetime(joined_all_df["dc_date"], errors="coerce")
    joined_all_df["contrib_date"] = pd.to_datetime(joined_all_df["contrib_date"], errors="coerce")

    score_cols = ["window_fundraising_count_score", "window_fundraising_amount_score"]
    for col in score_cols:
        joined_all_df[col] = pd.to_numeric(joined_all_df[col], errors="coerce")

    # --- 7. Pull only D and R records
    joined_score_df = joined_all_df[joined_all_df["dc_party"].isin(["D", "R"])].copy()

    # --- 8. Set score columns to 0 where dc_date is NaT
    mask_no_date = joined_score_df["dc_date"].isna()
    joined_score_df.loc[mask_no_date, score_cols] = 0

    # --- 9. Compute monthly averages (grouped by month) for amount and count scores
    joined_score_df["month_year"] = joined_score_df["contrib_date"].dt.to_period("M").dt.to_timestamp()

    monthly_avg_amount = (
        joined_score_df.groupby("month_year")
                       .agg(avg_month_amount=("window_fundraising_amount_score", "mean"))
                       .reset_index()
    )
    mean_monthly_avg_amount_score = monthly_avg_amount["avg_month_amount"].mean()

    monthly_avg_count = (
        joined_score_df.groupby("month_year")
                       .agg(avg_month_count=("window_fundraising_count_score", "mean"))
                       .reset_index()
    )
    mean_monthly_avg_count_score = monthly_avg_count["avg_month_count"].mean()

    # --- 10. Summarize results for this window length
    summary = {"input_window_days": days, "window_days": days + 1}
    for col in window_cols:
        summary[col + "_sum"] = temp_df[col].sum()
    summary["mean_monthly_avg_amount_score"] = mean_monthly_avg_amount_score
    summary["mean_monthly_avg_count_score"] = mean_monthly_avg_count_score

    test_results.append(summary)

# Combine into a summary DataFrame
test_summary_df = pd.DataFrame(test_results)

print(test_summary_df)
# Out:
#    input_window_days  window_days  window_contrib_count_sum  \
# 0                  0            1                     60596
# 1                  1            2                     98079
# 2                  2            3                    132296
# 3                  3            4                    166893
# 4                  4            5                    199726
# 5                  5            6                    228804
#
#    window_contrib_amount_sum  mean_monthly_avg_amount_score  \
# 0                   34918885                       3.692524
# 1                   52612248                       2.473218
# 2                   68583433                       2.054069
# 3                   85491542                       1.920388
# 4                  100921650                       1.867131
# 5                  114158925                       1.828481
#
#    mean_monthly_avg_count_score
# 0                      3.622249
# 1                      2.349133
# 2                      1.924568
# 3                      1.763973
# 4                      1.664508
# 5                      1.621572

# %%
# FIGURE: PARAMETER SWEEP TEST

# plt.figure(figsize=(7, 3.5))
fig, ax = plt.subplots(figsize=(3.5, 3.25))

sns.barplot(
    data=test_summary_df,
    x='window_days',
    y='mean_monthly_avg_amount_score',
    color=breakdown_color1,
    ax=ax,
    width=0.8   
)

# plt.title("Total Contributions to U.S. Representatives by Month (2015-2016)", pad = 30)
plt.xlabel("")
plt.ylabel("")
plt.yticks([])
# plt.xticks([])
# plt.xticks(rotation = 90, ha = 'right')
ax.set_xticks(range(len(test_summary_df)))
ax.set_xticklabels(test_summary_df['window_days'], rotation = 0, ha = 'center', fontsize = axis_labelsize)
ax.tick_params(axis='x', length = 0, pad = 5)

# Add axis labels
ax.set_xlabel("Number of days included in window", fontsize=axis_labelsize, labelpad=7.5) 
ax.set_ylabel("Average newsletter\nfundraising score", color='black', fontsize=axis_labelsize)
ax.spines['left'].set_color('lightgray')  # Light gray y-axis line

plt.tight_layout()

# Add data labels above each bar
for i, p in enumerate(ax.patches):
    height = p.get_height()
    ax.text(
        i,
        height + (.02 * test_summary_df['mean_monthly_avg_amount_score'].max()),
        f'{height:,.2f}',
        ha='center',
        va='bottom',
        rotation=0,
        fontsize=axis_labelsize,
        fontweight='medium'
    )

# Remove the outlines
sns.despine(top=True, right=True, left=True)

# Add padding so labels don’t hit the top edge
ymax = test_summary_df['mean_monthly_avg_amount_score'].max()
plt.ylim(0, ymax * 1.09)

# Add caption below the plot
plt.text(
    -0.0, # X position
    -0.24, # Y position
    "Includes only newsletters associated with contributions.",
    ha='left',
    va='center',
    fontsize = caption_size,
    color='#222222',
    transform=ax.transAxes # use axis coordinates so it scales with the figure
)

plt.show()
