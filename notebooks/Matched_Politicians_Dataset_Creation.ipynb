# %% [markdown]
# This notebook contains Helen's code merging the combined FEC / DC Inbox data set.

# %%
# import libraries
import pandas as pd
import numpy as np
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import unicodedata
import ftfy

# %%
# COLOR AND FONT SETTINGS FOR GRAPHS BELOW

# Palette for party breakdowns
# Uses the colorblind-safe RedBlues palette from Regenbogen
# Source: https://github.com/nrennie/PrettyCols
overall_color = "#acacac"
dem_light_color = "#93C6E1"
rep_light_color = "#D79C9C"
dem_med_color = "#5F93AC"
rep_med_color = "#C66969"
dem_dark_color = "#2E627A"
rep_dark_color = "#B53737"

# Palette for other breakdowns
# Uses the colorblind-safe VincentvanGogh_1 palette from Regenbogen
# Source: https://github.com/tylerlittlefield/lisa
breakdown_color1 = "#A7A651"
breakdown_color2 = "#E0BA7A"
breakdown_color3 = "#9BA7B0"
# breakdown_color4 = "#5A5F80"
breakdown_color4 = "#BFB9C9"

# e.g. darker_color = darken_hex(dem_med_color, 0.8)     # 20% darker

# Global Seaborn style settings
sns.set(
    style="whitegrid",
    rc={
        "axes.labelsize": 10,   # x/y axis labels
        "xtick.labelsize": 9,   # tick labels
        "ytick.labelsize": 9,
    }
)

# Optional alternative font settings
axis_titlesize = 10
axis_labelsize = 9
facet_titlesize = 9

# %%
# Read in the raw DCInbox table

dcinbox_raw_df = pd.read_csv(
    "../data/dcinbox/dcinbox_export_114.csv",
    # sep = ",",            # columns are separated by commas
    # encoding = "latin1",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    engine = 'python'    # This might be able to handle very long messages better
)

# Remove all unnamed columns, because they're messing up the read of the file
unnamed = dcinbox_raw_df.columns.str.contains('^Unnamed')
dcinbox_clean_columns_df = dcinbox_raw_df.loc[:, ~unnamed].copy()

print(len(dcinbox_clean_columns_df))
dcinbox_clean_columns_df.head()
# Out:
# 24224
#                                             Subject  \
# 0                                   Happy New Year!
# 1                                   Happy New Year!
# 2  OH-12 Update / A Look Back at the 114th Congress
# 3              The Leader's Daily Schedule - 1/3/17
# 4                         What I've Been Working On
#
#                                                 Body Unix Timestamp  \
# 0  Click here to open this e-mail in its own brow...    1.48339E+12
# 1  Several Issa-Backed Bills Become Law View this...    1.48338E+12
# 2   OH-12 Update / A Look Back at the 114th Congr...    1.48338E+12
# 3   The Leader's Daily Schedule - 1/3/17 Kevin Mc...    1.48337E+12
# 4   Click here to open this e-mail in its own bro...    1.48337E+12
#
#   BioGuide ID Congress First Name  Last Name Date of Birth Gender State  \
# 0     W000806      114     Daniel    Webster       4/27/49      M    FL
# 1     I000056      114    Darrell       Issa       11/1/53      M    CA
# 2     T000462      114    Patrick     Tiberi      10/21/62      M    OH
# 3     M001165      114      Kevin   McCarthy       1/26/65      M    CA
# 4     C001084      114      David  Cicilline       7/15/61      M    RI
#
#   District       Party Chamber Nickname      ID
# 0       10  Republican   House      NaN  136125
# 1       49  Republican   House      NaN  136126
# 2       12  Republican   House      Pat  136127
# 3       23  Republican   House      NaN  136128
# 4        1    Democrat   House      NaN  136129

# %%
# QC to make sure special characters are coming in okay in DC Inbox data

mask = dcinbox_clean_columns_df["Last Name"].str.contains(r'[^\x00-\x7F]', regex=True, na=False)
special_names = dcinbox_clean_columns_df[mask]

# Select only first and last name, and keep unique combinations
allowed_parties = ["Democrat", "Republican", "Other"]
unique_names = special_names[special_names["Party"].isin(allowed_parties)][["First Name", "Last Name", "Party"]].drop_duplicates()

print(unique_names)
# Out:
#      First Name  Last Name     Party
# 216        Tony   Cárdenas  Democrat
# 284       Linda    Sánchez  Democrat
# 512        Beto   O’Rourke  Democrat
# 4752      Nydia  Velázquez  Democrat
# 8418        Ben      Luján  Democrat

# %%
# Field cleanup for DC Inbox table & adding unique ID per newsletter

# dcinbox_df = dcinbox_clean_columns_df
dcinbox_df = dcinbox_clean_columns_df.copy()

# Convert unix timestamp to a datetime column
dcinbox_df["Date"] = pd.to_datetime(
    pd.to_numeric(dcinbox_df["Unix Timestamp"], errors="coerce"),
    unit="ms"
).dt.date

# Convert district to an integer and fill senators with 0
dcinbox_df["District"] = (
    pd.to_numeric(dcinbox_df["District"], errors = "coerce")
    .fillna(0)
    .astype(int)
)

# create a column that is the uppercased, concatenated first and last name of the politician
# (for matching later to Open Secrets data)
dcinbox_df["Full Name"] = dcinbox_df["First Name"].str.upper() + " " + dcinbox_df["Last Name"].str.upper()

# Rename party to party full
dcinbox_df.rename(columns={"Party": "Party Full"}, inplace=True)
# Add a new party column that just is one character mapped to D, R, or O (Other)
dcinbox_df["Party"] = (
    dcinbox_df["Party Full"]
    .fillna("")
    .astype(str)
    .str[0]
    .str.upper()
    .map({"D": "D", "R": "R"})
    .fillna("O")
)

# Make sure state and party are uppercased
dcinbox_df["State"] = dcinbox_df["State"].fillna("").str.strip().str.upper()
dcinbox_df["Party"] = dcinbox_df["Party"].str.upper()

# Add a unique ID for each newsletter (based on the index row)
dcinbox_df["newsletter_id"] = ["NL" + str(i).zfill(6) for i in range(1, len(dcinbox_df) + 1)]

print(len(dcinbox_df))
print(dcinbox_df["newsletter_id"].nunique())
dcinbox_df.head()
# Out:
# 24224
# 24224
#                                             Subject  \
# 0                                   Happy New Year!
# 1                                   Happy New Year!
# 2  OH-12 Update / A Look Back at the 114th Congress
# 3              The Leader's Daily Schedule - 1/3/17
# 4                         What I've Been Working On
#
#                                                 Body Unix Timestamp  \
# 0  Click here to open this e-mail in its own brow...    1.48339E+12
# 1  Several Issa-Backed Bills Become Law View this...    1.48338E+12
# 2   OH-12 Update / A Look Back at the 114th Congr...    1.48338E+12
# 3   The Leader's Daily Schedule - 1/3/17 Kevin Mc...    1.48337E+12
# 4   Click here to open this e-mail in its own bro...    1.48337E+12
#
#   BioGuide ID Congress First Name  Last Name Date of Birth Gender State  \
# 0     W000806      114     Daniel    Webster       4/27/49      M    FL
# 1     I000056      114    Darrell       Issa       11/1/53      M    CA
# 2     T000462      114    Patrick     Tiberi      10/21/62      M    OH
# 3     M001165      114      Kevin   McCarthy       1/26/65      M    CA
# 4     C001084      114      David  Cicilline       7/15/61      M    RI
#
#    District  Party Full Chamber Nickname      ID        Date        Full Name  \
# 0        10  Republican   House      NaN  136125  2017-01-02   DANIEL WEBSTER
# 1        49  Republican   House      NaN  136126  2017-01-02     DARRELL ISSA
# 2        12  Republican   House      Pat  136127  2017-01-02   PATRICK TIBERI
# 3        23  Republican   House      NaN  136128  2017-01-02   KEVIN MCCARTHY
# 4         1    Democrat   House      NaN  136129  2017-01-02  DAVID CICILLINE
#
#   Party newsletter_id
# 0     R      NL000001
# 1     R      NL000002
# 2     R      NL000003
# 3     R      NL000004
# 4     D      NL000005

# %%
# QC to make sure special characters are still coming in okay in DC Inbox data

mask = dcinbox_df["Full Name"].str.contains(r'[^\x00-\x7F]', regex=True, na=False)
special_names = dcinbox_df[mask]

# Select only first and last name, and keep unique combinations
allowed_parties = ["D", "R"]
unique_names = special_names[special_names["Party"].isin(allowed_parties)][["Full Name", "Party"]].drop_duplicates()

print(unique_names)
# Out:
#              Full Name Party
# 89        ANDRÉ CARSON     D
# 193      RAÚL LABRADOR     R
# 216      TONY CÁRDENAS     D
# 284      LINDA SÁNCHEZ     D
# 512      BETO O’ROURKE     D
# 2418      JOSÉ SERRANO     D
# 3409     RAÚL GRIJALVA     D
# 4752   NYDIA VELÁZQUEZ     D
# 8418         BEN LUJÁN     D
# 14437   RUBÉN HINOJOSA     D

# %%
# Read in the matched politicians table

column_names = ["target_id", "dcinbox_name", "fec_cid", "fec_name",
                "fec_party", "fec_state", "fec_district",
                "fec_cycle", "append_attribute2", "append_attribute3",
                "similarity_score", "matched_scorer"]

matched_pols_df = pd.read_csv(
    "../data/matched/matched_politicians_2016_75.csv",
    encoding = "latin1",
    # encoding="cp1252",
    # encoding="utf-8",
    # encoding="utf-8-sig",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    names = column_names,
    header = 0
)

print(len(matched_pols_df))
matched_pols_df.head()
# Out:
# 396
#    target_id     dcinbox_name    fec_cid         fec_name fec_party fec_state  \
# 0        NaN   DANIEL WEBSTER  N00026335   DANIEL WEBSTER         R        FL
# 1        NaN     DARRELL ISSA  N00007017     DARRELL ISSA         R        CA
# 2        NaN   PATRICK TIBERI  N00009699       PAT TIBERI         R        OH
# 3        NaN   KEVIN MCCARTHY  N00028152   KEVIN MCCARTHY         R        CA
# 4        NaN  DAVID CICILLINE  N00032019  DAVID CICILLINE         D        RI
#
#    fec_district  fec_cycle  append_attribute2  append_attribute3  \
# 0            10       2016                NaN                NaN
# 1            49       2016                NaN                NaN
# 2            12       2016                NaN                NaN
# 3            23       2016                NaN                NaN
# 4             1       2016                NaN                NaN
#
#    similarity_score matched_scorer
# 0        100.000000         WRatio
# 1        100.000000         WRatio
# 2         83.333333         WRatio
# 3        100.000000         WRatio
# 4        100.000000         WRatio

# %%
# Fix the special characters in the matching file back to their original form

# Fix special characters

def fix_latin1_encoding(text):
    if isinstance(text, str):
        # Convert string to bytes using latin1, then decode as utf-8
        try:
            return text.encode('latin1').decode('utf-8')
        except UnicodeDecodeError:
            # If it fails, just return original text
            return text
    return text

matched_pols_df["dcinbox_name"] = matched_pols_df["dcinbox_name"].apply(fix_latin1_encoding)

# Fix weird apostrophes

def clean_names(text):
    if not isinstance(text, str):
        return text
    
    # Step 1: fix general mojibake
    fixed = ftfy.fix_text(text)
    
    # Step 2: replace common mojibake apostrophes
    fixed = fixed.replace("€™", "'").replace("â€™", "'").replace("â€˜", "'")
    
    return fixed

matched_pols_df["dcinbox_name"] = matched_pols_df["dcinbox_name"].apply(clean_names)

# %%
# QC to make sure special characters are coming in okay in matched data file

beto_df = matched_pols_df[matched_pols_df["dcinbox_name"].str.contains("ROURKE")]
print(beto_df[["dcinbox_name", "fec_name"]])

mask = matched_pols_df["dcinbox_name"].str.contains(r'[^\x00-\x7F]', regex=True, na=False)
special_names = matched_pols_df[mask]

print(special_names[["dcinbox_name", "fec_name"]])
# Out:
#       dcinbox_name       fec_name
# 211  BETO O'ROURKE  BETO O'ROURKE
#         dcinbox_name         fec_name
# 62      ANDRÉ CARSON     ANDRE CARSON
# 108    RAÚL LABRADOR    RAUL LABRADOR
# 124    TONY CÁRDENAS    TONY CARDENAS
# 157    LINDA SÁNCHEZ    LINDA SANCHEZ
# 308     JOSÉ SERRANO   JOSE E SERRANO
# 325    RAÚL GRIJALVA  RAUL M GRIJALVA
# 338  NYDIA VELÁZQUEZ  NYDIA VELAZQUEZ
# 356        BEN LUJÁN      BEN R LUJAN
# 382   RUBÉN HINOJOSA   RUBEN HINOJOSA

# %%
# Read in the summarized FEC candidate contributions file

cand_contribs_raw_df = pd.read_csv(
    "../data/fec/candidate_contributions_2016.csv",
    encoding = "latin1"
)

# Drop the columns we don't need
cand_contribs_raw_df = cand_contribs_raw_df.drop(columns=['DistIDRunFor', 'DistIDCurr', "CurrCand", "CycleCand", 
                                                  "RecipCode", "CRPICO", "FECCandID"])

print(len(cand_contribs_raw_df))
cand_contribs_raw_df.head()
# Out:
# 94669
#    Cycle        CID   FirstLastP Party Original NoPacs State  District Party  \
# 0   2016  N00030768  MARTHA ROBY              R           AL         2     R
# 1   2016  N00030768  MARTHA ROBY              R           AL         2     R
# 2   2016  N00030768  MARTHA ROBY              R           AL         2     R
# 3   2016  N00030768  MARTHA ROBY              R           AL         2     R
# 4   2016  N00030768  MARTHA ROBY              R           AL         2     R
#
#   contrib_date  contrib_count  contrib_amount
# 0   2015-02-11              1           250.0
# 1   2015-02-18              2          1478.0
# 2   2015-02-26              1          2700.0
# 3   2015-03-02             26         40350.0
# 4   2015-03-11              1          1000.0

# %%
# Add averages for year and month to candidate contributions dataframe (for normalizing later)

# Rename columns so they won't clash with the DC Inbox data file
cand_contribs_raw_df = cand_contribs_raw_df.rename(columns={
    "Cycle": "fec_cycle",
    "CID": "fec_cid",
    "FirstLastP": "fec_name",
    "Party Original": "fec_party_original",
    "NoPacs": "no_pacs",
    "State": "fec_state",
    "District": "fec_district",
    "Party": "fec_party"    
})

# Set correct types on some columns
cand_contribs_raw_df["contrib_count"] = cand_contribs_raw_df["contrib_count"].fillna(0)
cand_contribs_raw_df["contrib_amount"] = cand_contribs_raw_df["contrib_amount"].fillna(0).astype(int)

# Set contrib_date to datetime
cand_contribs_raw_df["contrib_date"] = pd.to_datetime(cand_contribs_raw_df["contrib_date"])

# Define the full date range
start_date = pd.Timestamp("2015-01-03")
end_date = pd.Timestamp("2017-01-02")
num_days = (end_date - start_date).days + 1  # inclusive

# Filter to target period
mask = (cand_contribs_raw_df["contrib_date"] >= start_date) & (cand_contribs_raw_df["contrib_date"] <= end_date)
cand_contribs_df = cand_contribs_raw_df.loc[mask].copy()

# Remove full-period daily averages -- we're using monthly averages instead

# Groupby for full-period averages
# total_stats = (
#     cand_contribs_df.groupby(["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party"], dropna=False)
#     .agg(
#         total_contrib_count=("contrib_count", "sum"),
#         total_contrib_amount=("contrib_amount", "sum")
#     )
#     .reset_index()
# )

# Calculate full-period daily averages
# total_stats["avg_daily_contrib_count"] = total_stats["total_contrib_count"] / num_days
# total_stats["avg_daily_contrib_amount"] = total_stats["total_contrib_amount"] / num_days

# Merge in full-period averages
# cand_contribs_df = cand_contribs_df.merge(
#     total_stats[["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party", 
#                  "avg_daily_contrib_count", "avg_daily_contrib_amount"]],
#     on=["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party"],
#     how="left"
# )

# Monthly averages
cand_contribs_df['month_start'] = cand_contribs_df['contrib_date'].values.astype('datetime64[M]')

monthly_stats = (
    cand_contribs_df.groupby(["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party", "month_start"], dropna=False)
    .agg(
        monthly_contrib_count=('contrib_count', 'sum'),
        monthly_contrib_amount=('contrib_amount', 'sum')
    )
    .reset_index()
)

monthly_stats['days_in_month'] = monthly_stats['month_start'].dt.days_in_month
monthly_stats['avg_month_daily_contrib_count'] = monthly_stats['monthly_contrib_count'] / monthly_stats['days_in_month']
monthly_stats['avg_month_daily_contrib_amount'] = monthly_stats['monthly_contrib_amount'] / monthly_stats['days_in_month']

# Merge in monthly averages
cand_contribs_df = cand_contribs_df.merge(
    monthly_stats[['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party', 'month_start',
                   'avg_month_daily_contrib_count', 'avg_month_daily_contrib_amount']],
    on=['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party', 'month_start'],
    how='left'
)

# Remove to-date daily averages -- we're using monthly averages instead

# Calculate to-date daily averages
# cand_contribs_df = cand_contribs_df.sort_values(
#     ['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party', 'contrib_date']
# ).copy()

# cand_contribs_df['days_since_start'] = (cand_contribs_df['contrib_date'] - start_date).dt.days + 1

# cand_contribs_df['cumsum_contrib_count'] = cand_contribs_df.groupby(
#     ['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party']
# )['contrib_count'].cumsum()

# cand_contribs_df['cumsum_contrib_amount'] = cand_contribs_df.groupby(
#     ['fec_name', 'fec_cycle', 'fec_state', 'fec_district', 'fec_party']
# )['contrib_amount'].cumsum()

# cand_contribs_df['avg_daily_contrib_count_td'] = cand_contribs_df['cumsum_contrib_count'] / cand_contribs_df['days_since_start']
# cand_contribs_df['avg_daily_contrib_amount_td'] = cand_contribs_df['cumsum_contrib_amount'] / cand_contribs_df['days_since_start']

# Drop temporary columns
# cand_contribs_df = cand_contribs_df.drop(columns=['cumsum_contrib_count', 'cumsum_contrib_amount', 'days_since_start'])

cand_contribs_df.head()
# Out:
#    fec_cycle    fec_cid     fec_name fec_party_original no_pacs fec_state  \
# 0       2016  N00030768  MARTHA ROBY                  R                AL
# 1       2016  N00030768  MARTHA ROBY                  R                AL
# 2       2016  N00030768  MARTHA ROBY                  R                AL
# 3       2016  N00030768  MARTHA ROBY                  R                AL
# 4       2016  N00030768  MARTHA ROBY                  R                AL
#
#    fec_district fec_party contrib_date  contrib_count  contrib_amount  \
# 0             2         R   2015-02-11              1             250
# 1             2         R   2015-02-18              2            1478
# 2             2         R   2015-02-26              1            2700
# 3             2         R   2015-03-02             26           40350
# 4             2         R   2015-03-11              1            1000
#
#   month_start  avg_month_daily_contrib_count  avg_month_daily_contrib_amount
# 0  2015-02-01                       0.142857                      158.142857
# 1  2015-02-01                       0.142857                      158.142857
# 2  2015-02-01                       0.142857                      158.142857
# 3  2015-03-01                       1.838710                     3079.032258
# 4  2015-03-01                       1.838710                     3079.032258

# %%
# Read in the newsletter emotion data

# Democrats
dem_emotion_raw_df = pd.read_csv(
    "../data/emotion_scores/democrat_emails_emotions.csv",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    engine = 'python'    # This might be able to handle very long messages better
)

# Democrats
rep_emotion_raw_df = pd.read_csv(
    "../data/emotion_scores/republican_emails_emotions.csv",
    quotechar = '"',   # Make sure actual quotation marks in newsletters are handled right
    engine = 'python'    # This might be able to handle very long messages better
)

print("Rows in democrat emotion file: ", len(dem_emotion_raw_df))
print("Rows in republican emotion file: ", len(rep_emotion_raw_df))
rep_emotion_raw_df.head()
# Out:
# Rows in democrat emotion file:  2836
# Rows in republican emotion file:  7181
#                   date first_name  last_name  \
# 0  2016-01-01 09:20:00     Marsha  Blackburn
# 1  2016-01-01 09:20:00       John  Ratcliffe
# 2  2016-01-01 09:20:00        Bob       Dold
# 3  2016-01-01 09:20:00       Reid     Ribble
# 4  2016-01-01 12:06:40      Scott      Perry
#
#                                         subject  joy_score  neutral_score  \
# 0                        2015: A Year in Review   0.865618       0.087187
# 1  A good year behind us and a better one ahead   0.051047       0.853077
# 2                             Need your opinion   0.077292       0.849178
# 3                               Happy New Year!   0.486362       0.322856
# 4                                Happy New Year   0.538033       0.191443
#
#    surprise_score  fear_score  sadness_score  anger_score  disgust_score
# 0        0.014608    0.013100       0.011757          NaN            NaN
# 1        0.014838    0.010486       0.063951          NaN            NaN
# 2        0.043608    0.005638       0.015904          NaN            NaN
# 3        0.059834         NaN       0.116793     0.008147            NaN
# 4        0.074743         NaN       0.187607     0.004052            NaN

# %%
# Join the democrat and republican emotion files together

emotion_raw_df = pd.concat([rep_emotion_raw_df, dem_emotion_raw_df], ignore_index=True)
print(len(emotion_raw_df))
# Out:
# 10017

# %%
# Add columns to emotion data to match equivalent join columns in dcinbox data

emotion_clean_df = emotion_raw_df.copy()

# use dcinbox formatted dates
emotion_clean_df['date'] = pd.to_datetime(emotion_clean_df['date']).dt.strftime('%Y-%m-%d')

# concatenate first and last names into uppercased full name
emotion_clean_df['full_name'] = emotion_clean_df['first_name'].fillna('') + ' ' + emotion_clean_df['last_name'].fillna('')
emotion_clean_df['full_name'] = emotion_clean_df['full_name'].str.strip()  
emotion_clean_df['full_name'] = emotion_clean_df['full_name'].str.upper()

print(len(emotion_clean_df))
emotion_clean_df.head()
# Out:
# 10017
#          date first_name  last_name  \
# 0  2016-01-01     Marsha  Blackburn
# 1  2016-01-01       John  Ratcliffe
# 2  2016-01-01        Bob       Dold
# 3  2016-01-01       Reid     Ribble
# 4  2016-01-01      Scott      Perry
#
#                                         subject  joy_score  neutral_score  \
# 0                        2015: A Year in Review   0.865618       0.087187
# 1  A good year behind us and a better one ahead   0.051047       0.853077
# 2                             Need your opinion   0.077292       0.849178
# 3                               Happy New Year!   0.486362       0.322856
# 4                                Happy New Year   0.538033       0.191443
#
#    surprise_score  fear_score  sadness_score  anger_score  disgust_score  \
# 0        0.014608    0.013100       0.011757          NaN            NaN
# 1        0.014838    0.010486       0.063951          NaN            NaN
# 2        0.043608    0.005638       0.015904          NaN            NaN
# 3        0.059834         NaN       0.116793     0.008147            NaN
# 4        0.074743         NaN       0.187607     0.004052            NaN
#
#           full_name
# 0  MARSHA BLACKBURN
# 1    JOHN RATCLIFFE
# 2          BOB DOLD
# 3       REID RIBBLE
# 4       SCOTT PERRY

# %%
# Add text-parsing columns to dcinbox data 
# including word count, fundraising term count, and
# ratio of fundraising terms found to total words

# --- Load and clean term list ---
terms_df = pd.read_csv("../data/dcinbox/fundraising_terms.csv")
term_roots = terms_df['term'].dropna().unique().tolist()

# Build a single regex pattern that matches any of the roots, case-insensitive
# Use word boundaries to avoid partial matches inside other words
term_pattern = re.compile(r'\b(?:' + '|'.join(re.escape(t) for t in term_roots) + r')\w*\b', flags=re.IGNORECASE)

# --- Load and process DC Inbox data ---
dcinbox_df['Date'] = pd.to_datetime(dcinbox_df['Date'])

# Create newsletter count column (for use downstream)
dcinbox_df["newsletter_count"] = 1

# Create word count column
dcinbox_df['body_word_count'] = dcinbox_df['Body'].str.split().str.len()

# Count fundraising term appearances in Body
def count_terms(text):
    if pd.isna(text):
        return 0
    return len(term_pattern.findall(text))

dcinbox_df['fundraising_terms'] = dcinbox_df['Body'].apply(count_terms)

# print("Sample fundraising term counts:")
# print(dcinbox_df[['Full Name', 'Date', 'fundraising_terms']].head())

# Compute per-newsletter fundraising ratio
dcinbox_df['fundraising_ratio'] = dcinbox_df.apply(
    lambda x: x['fundraising_terms'] / x['body_word_count'] if x['body_word_count'] > 0 else 0, axis=1
)

# Compute total newsletters per politician
dcinbox_df["total_newsletters"] = dcinbox_df.groupby("Full Name")["newsletter_count"].transform("sum")

# Removed summarizing step, because we want to have the dcinbox dataframe keyed by newsletter ID, not politician/day

# --- Summarize by politician and day ---
# dcinbox_summary_df = dcinbox_df.groupby(['Full Name', 'Date'], as_index=False).agg(
#     newsletter_count=('Subject', 'count'),
#     body_word_count_sum=('body_word_count', 'sum'),
#     fundraising_terms_sum=('fundraising_terms', 'sum'),
#     fundraising_ratio_mean=('fundraising_ratio', 'mean')  # average ratio per newsletter
# )

# Merge back other columns using the first occurrence per day for all other columns
# other_cols = [
#     col for col in dcinbox_df.columns 
#     if col not in ['Subject', 'Body', 'body_word_count', 'Date', 'Full Name', 
#                    'Party Truncated', 'fundraising_terms', 'fundraising_ratio']
# ]
# dcinbox_summary_df = dcinbox_summary_df.merge(
#     dcinbox_df.groupby(['Full Name', 'Date'])[other_cols].first().reset_index(),
#     on=['Full Name', 'Date'],
#     how='left'
# )

print("Rows in dcinbox_df:", len(dcinbox_df))
# Out:
# Rows in dcinbox_df: 24224

# %%
# Filter dcinbox data to only keep house members & needed columns

# Keep only House members
dcinbox_filtered_df = dcinbox_df[dcinbox_df["Chamber"] == "House"]

# Drop unneeded columns
dcinbox_filtered_df = dcinbox_filtered_df.drop(
    columns=['Body', 'Nickname', 'Date of Birth', "First Name", "Last Name", "BioGuide ID", "Unix Timestamp"],
    errors='ignore'
)

print("Records in dcinbox_filtered_df:", len(dcinbox_filtered_df))
print("newsletter count:", dcinbox_filtered_df["newsletter_count"].sum())

dcinbox_filtered_df.head()
# Out:
# Records in dcinbox_filtered_df: 20582
# newsletter count: 20582
#                                             Subject Congress Gender State  \
# 0                                   Happy New Year!      114      M    FL
# 1                                   Happy New Year!      114      M    CA
# 2  OH-12 Update / A Look Back at the 114th Congress      114      M    OH
# 3              The Leader's Daily Schedule - 1/3/17      114      M    CA
# 4                         What I've Been Working On      114      M    RI
#
#    District  Party Full Chamber      ID       Date        Full Name Party  \
# 0        10  Republican   House  136125 2017-01-02   DANIEL WEBSTER     R
# 1        49  Republican   House  136126 2017-01-02     DARRELL ISSA     R
# 2        12  Republican   House  136127 2017-01-02   PATRICK TIBERI     R
# 3        23  Republican   House  136128 2017-01-02   KEVIN MCCARTHY     R
# 4         1    Democrat   House  136129 2017-01-02  DAVID CICILLINE     D
#
#   newsletter_id  newsletter_count  body_word_count  fundraising_terms  \
# 0      NL000001                 1              690                  1
# 1      NL000002                 1              435                  0
# 2      NL000003                 1              620                  0
# 3      NL000004                 1              179                  0
# 4      NL000005                 1              192                  0
#
#    fundraising_ratio  total_newsletters
# 0           0.001449               96.0
# 1           0.000000                9.0
# 2           0.000000               29.0
# 3           0.000000              304.0
# 4           0.000000              103.0

# %%
# Join emotion terms to filtered dcinbox dataframe

print(len(dcinbox_filtered_df))

# Make sure both dataframes have the same date format
dcinbox_filtered_df['Date'] = pd.to_datetime(dcinbox_filtered_df['Date'])
emotion_clean_df['date'] = pd.to_datetime(emotion_clean_df['date'])

dcinbox_emotion_df = dcinbox_filtered_df.merge(
    emotion_clean_df,
    left_on = ["Full Name", "Date", "Subject"],
    right_on = ["full_name", "date", "subject"],
    how = 'left'
)

# Drop the columns we don't need
dcinbox_emotion_df = dcinbox_emotion_df.drop(columns=["full_name", "date", "subject", "first_name", "last_name"])

print(dcinbox_filtered_df.columns)
print(dcinbox_emotion_df.columns)

print(len(dcinbox_emotion_df))
dcinbox_emotion_df.head()
# Out:
# 20582
# Index(['Subject', 'Congress', 'Gender', 'State', 'District', 'Party Full',
#        'Chamber', 'ID', 'Date', 'Full Name', 'Party', 'newsletter_id',
#        'newsletter_count', 'body_word_count', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters'],
#       dtype='object')
# Index(['Subject', 'Congress', 'Gender', 'State', 'District', 'Party Full',
#        'Chamber', 'ID', 'Date', 'Full Name', 'Party', 'newsletter_id',
#        'newsletter_count', 'body_word_count', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters', 'joy_score', 'neutral_score',
#        'surprise_score', 'fear_score', 'sadness_score', 'anger_score',
#        'disgust_score'],
#       dtype='object')
# 20660
#                                             Subject Congress Gender State  \
# 0                                   Happy New Year!      114      M    FL
# 1                                   Happy New Year!      114      M    CA
# 2  OH-12 Update / A Look Back at the 114th Congress      114      M    OH
# 3              The Leader's Daily Schedule - 1/3/17      114      M    CA
# 4                         What I've Been Working On      114      M    RI
#
#    District  Party Full Chamber      ID       Date        Full Name  ...  \
# 0        10  Republican   House  136125 2017-01-02   DANIEL WEBSTER  ...
# 1        49  Republican   House  136126 2017-01-02     DARRELL ISSA  ...
# 2        12  Republican   House  136127 2017-01-02   PATRICK TIBERI  ...
# 3        23  Republican   House  136128 2017-01-02   KEVIN MCCARTHY  ...
# 4         1    Democrat   House  136129 2017-01-02  DAVID CICILLINE  ...
#
#   fundraising_terms fundraising_ratio  total_newsletters  joy_score  \
# 0                 1          0.001449               96.0        NaN
# 1                 0          0.000000                9.0        NaN
# 2                 0          0.000000               29.0        NaN
# 3                 0          0.000000              304.0        NaN
# 4                 0          0.000000              103.0        NaN
#
#    neutral_score  surprise_score  fear_score  sadness_score  anger_score  \
# 0            NaN             NaN         NaN            NaN          NaN
# 1            NaN             NaN         NaN            NaN          NaN
# 2            NaN             NaN         NaN            NaN          NaN
# 3            NaN             NaN         NaN            NaN          NaN
# 4            NaN             NaN         NaN            NaN          NaN
#
#    disgust_score
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 24 columns]

# %%
# QC to find duplicates in joined data

dc_dupes = dcinbox_filtered_df[dcinbox_filtered_df.duplicated(subset=["Full Name", "Date", "Subject"], keep=False)]
print("Number of duplicates in dcinbox_filtered_df:", len(dc_dupes))
# print(dc_dupes)
 
duplicates = emotion_clean_df[emotion_clean_df.duplicated(subset=['full_name', 'date', 'subject'], keep=False)]
print("Number of duplicates in emotion_clean_df:", len(duplicates))
print(duplicates)
# Out:
# Number of duplicates in dcinbox_filtered_df: 133
# Number of duplicates in emotion_clean_df: 59
#            date first_name   last_name  \
# 49   2016-01-05       Doug     Lamborn
# 50   2016-01-05       Doug     Lamborn
# 254  2016-01-14      David        Brat
# 255  2016-01-14      David        Brat
# 499  2016-01-28    Patrick      Meehan
# 500  2016-01-28    Patrick      Meehan
# 581  2016-02-01        Sam     Johnson
# 586  2016-02-01        Sam     Johnson
# 639  2016-02-04       Doug     Lamborn
# 640  2016-02-04       Doug     Lamborn
# 1415 2016-03-10      Louie     Gohmert
# 1416 2016-03-10      Louie     Gohmert
# 2079 2016-04-13        Dan    Newhouse
# 2081 2016-04-13        Dan    Newhouse
# 2129 2016-04-15         Ed   Whitfield
# 2137 2016-04-15         Ed   Whitfield
# 2445 2016-04-28        Dan    Newhouse
# 2446 2016-04-28        Dan    Newhouse
# 2860 2016-05-16       Sean       Duffy
# 2861 2016-05-16       Sean       Duffy
# 2866 2016-05-16       Sean       Duffy
# 2868 2016-05-16       Sean       Duffy
# 3529 2016-06-13        Tim   Huelskamp
# 3540 2016-06-13        Tim   Huelskamp
# 4685 2016-08-10       John   Ratcliffe
# 4687 2016-08-10       John   Ratcliffe
# 4692 2016-08-10       John   Ratcliffe
# 4693 2016-08-10       John   Ratcliffe
# 5764 2016-10-05     Dennis        Ross
# 5769 2016-10-05     Dennis        Ross
# 6530 2016-11-18     Marsha   Blackburn
# 6533 2016-11-18     Marsha   Blackburn
# 6608 2016-11-21     Martha        Roby
# 6612 2016-11-21     Martha        Roby
# 6818 2016-12-05       Raúl    Labrador
# 6823 2016-12-05       Raúl    Labrador
# 7241 2016-01-11       Raúl    Grijalva
# 7242 2016-01-11       Raúl    Grijalva
# 7305 2016-01-15   Gregorio      Sablan
# 7306 2016-01-15   Gregorio      Sablan
# 7507 2016-02-10      David   Cicilline
# 7513 2016-02-10      David   Cicilline
# 7640 2016-02-26       Mark       Pocan
# 7644 2016-02-26       Mark       Pocan
# 8293 2016-05-13       Mark  DeSaulnier
# 8294 2016-05-13       Mark  DeSaulnier
# 8622 2016-06-22      Nancy      Pelosi
# 8624 2016-06-22      Nancy      Pelosi
# 8862 2016-07-18    Richard       Nolan
# 8867 2016-07-18    Richard       Nolan
# 9021 2016-08-05   Gregorio      Sablan
# 9023 2016-08-05   Gregorio      Sablan
# 9219 2016-09-03        Joe    Courtney
# 9220 2016-09-03        Joe    Courtney
# 9221 2016-09-03        Joe    Courtney
# 9709 2016-11-10       Eric    Swalwell
# 9718 2016-11-10       Eric    Swalwell
# 9951 2016-12-19       Eric    Swalwell
# 9954 2016-12-19       Eric    Swalwell
#
#                                                 subject  joy_score  \
# 49                       Attacking the Second Amendment        NaN
# 50                       Attacking the Second Amendment        NaN
# 254                          Responding to Your Message   0.132560
# 255                          Responding to Your Message   0.132560
# 499                   an update -- and a quick question        NaN
# 500                   an update -- and a quick question        NaN
# 581                           Response from Sam Johnson   0.293449
# 586                           Response from Sam Johnson   0.181648
# 639    Stopping Financial Harassment of Gun Businesses    0.011616
# 640    Stopping Financial Harassment of Gun Businesses         NaN
# 1415  Gohmert Pays Tribute to Former First Lady Nanc...   0.077430
# 1416  Gohmert Pays Tribute to Former First Lady Nanc...   0.077430
# 2079  Rep. Dan Newhouse Wants to Connect with You on...   0.013851
# 2081  Rep. Dan Newhouse Wants to Connect with You on...   0.013851
# 2129     Ed's Weekly Wrap-Up for Friday_ April 15_ 2016   0.042809
# 2137     Ed's Weekly Wrap-Up for Friday_ April 15_ 2016   0.042809
# 2445                 Would you read a 74,000 page book?   0.064695
# 2446                 Would you read a 74,000 page book?   0.064695
# 2860                We Must Protect Wisconsin Taxpayers   0.041213
# 2861                We Must Protect Wisconsin Taxpayers   0.041213
# 2866                We Must Protect Wisconsin Taxpayers   0.041213
# 2868                We Must Protect Wisconsin Taxpayers   0.041213
# 3529                    Another Attack by radical Islam        NaN
# 3540                    Another Attack by radical Islam        NaN
# 4685                                     You're Invited   0.010507
# 4687                                     You're Invited   0.008640
# 4692                                     You're Invited   0.012306
# 4693                                     You're Invited   0.010078
# 5764                             Hurricane Preparedness        NaN
# 5769                             Hurricane Preparedness        NaN
# 6530                  This Week From The District 11/18   0.353920
# 6533                  This Week From The District 11/18   0.339859
# 6608                    Sessions: The Right Pick for AG   0.860039
# 6612                    Sessions: The Right Pick for AG        NaN
# 6818  ICYMI: 7 Reasons We're Excited About the Capit...   0.534424
# 6823  ICYMI: 7 Reasons We're Excited About the Capit...   0.481183
# 7241            Here to Serve You: Priorities for 2016    0.016619
# 7242            Here to Serve You: Priorities for 2016    0.016619
# 7305            e-Newsletter - Friday, January 15, 2016   0.199008
# 7306            e-Newsletter - Friday, January 15, 2016   0.142756
# 7507                            Top Priorities for 2016   0.043121
# 7513                            Top Priorities for 2016   0.043121
# 7640                     Pocan Post: It's Budget Season   0.033722
# 7644                     Pocan Post: It's Budget Season   0.038141
# 8293                  Have you seen our website lately?   0.027002
# 8294                  Have you seen our website lately?   0.025260
# 8622                                  No Bill, No Break        NaN
# 8624                                  No Bill, No Break   0.000969
# 8862                     Supporting new Iron Range jobs   0.208599
# 8867                     Supporting new Iron Range jobs   0.101707
# 9021     This Week in Congress - Friday, August 5, 2016   0.205934
# 9023     This Week in Congress - Friday, August 5, 2016   0.202205
# 9219   A Groton-based crew breaks another glass ceiling   0.796031
# 9220   A Groton-based crew breaks another glass ceiling   0.796031
# 9221   A Groton-based crew breaks another glass ceiling   0.796031
# 9709                         Help me honor our Veterans   0.025841
# 9718                         Help me honor our Veterans   0.025841
# 9951                        As 2016 draws to a close...   0.022446
# 9954                        As 2016 draws to a close...   0.022446
#
#       neutral_score  surprise_score  fear_score  sadness_score  anger_score  \
# 49         0.151890             NaN    0.241393       0.021471     0.529311
# 50         0.151890             NaN    0.241393       0.021471     0.529311
# 254        0.698929        0.023620    0.110662       0.024759          NaN
# 255        0.698929        0.023620    0.110662       0.024759          NaN
# 499        0.893330        0.018326    0.049905       0.015254     0.010975
# 500        0.893330        0.018326    0.049905       0.015254     0.010975
# 581        0.531005        0.097745         NaN       0.066280     0.004654
# 586        0.706581        0.090082         NaN       0.011495     0.005617
# 639        0.201261             NaN    0.657540            NaN     0.087546
# 640        0.089150        0.006659    0.762288            NaN     0.103708
# 1415       0.024465        0.018371    0.114479       0.757311          NaN
# 1416       0.024465        0.018371    0.114479       0.757311          NaN
# 2079       0.924192        0.041068    0.007930            NaN     0.005744
# 2081       0.924192        0.041068    0.007930            NaN     0.005744
# 2129       0.798061        0.103928    0.011596       0.032586          NaN
# 2137       0.798061        0.103928    0.011596       0.032586          NaN
# 2445       0.836776        0.029470         NaN       0.055209     0.006729
# 2446       0.836776        0.029470         NaN       0.055209     0.006729
# 2860       0.578293             NaN    0.110180       0.138509     0.082265
# 2861       0.578293             NaN    0.110180       0.138509     0.082265
# 2866       0.578293             NaN    0.110180       0.138509     0.082265
# 2868       0.578293             NaN    0.110180       0.138509     0.082265
# 3529       0.024012             NaN    0.582708       0.071872     0.046061
# 3540       0.027894             NaN    0.755720       0.109778     0.038533
# 4685       0.257368        0.012293    0.705401       0.007797          NaN
# 4687       0.182777        0.010376    0.784874       0.006435          NaN
# 4692       0.261960        0.012619    0.698935       0.007361          NaN
# 4693       0.266924        0.011731    0.696376       0.008125          NaN
# 5764       0.524206        0.010087    0.404680       0.024849     0.023684
# 5769       0.539823        0.010006    0.389856       0.024288     0.023459
# 6530       0.522213        0.033785    0.050838       0.016630          NaN
# 6533       0.546435        0.037338    0.040772            NaN     0.014851
# 6608       0.108131        0.018800    0.003340       0.004973          NaN
# 6612       0.343137        0.035068    0.018784       0.550079          NaN
# 6818       0.332419        0.101705    0.010175       0.012537          NaN
# 6823       0.222035        0.263158    0.017990            NaN     0.008482
# 7241       0.925242        0.012538    0.018014       0.017285          NaN
# 7242       0.925242        0.012538    0.018014       0.017285          NaN
# 7305       0.727676        0.051859         NaN       0.009834     0.005430
# 7306       0.775554        0.060175         NaN       0.010128     0.006121
# 7507       0.927923        0.012131         NaN       0.004724     0.005297
# 7513       0.927923        0.012131         NaN       0.004724     0.005297
# 7640       0.911630        0.020616         NaN       0.021124     0.005638
# 7644       0.909494        0.022270         NaN       0.017562     0.005599
# 8293       0.785235        0.047083    0.123152            NaN     0.009269
# 8294       0.816862        0.049478    0.090604            NaN     0.009597
# 8622       0.001010        0.001013    0.993749       0.001669     0.001487
# 8624            NaN        0.000646    0.994946       0.001449     0.001368
# 8862       0.739595        0.013399         NaN       0.012346     0.012190
# 8867       0.826991        0.034602         NaN       0.022456     0.007299
# 9021       0.501249        0.220229         NaN       0.037482     0.024927
# 9023       0.508580        0.216906         NaN       0.037295     0.024914
# 9219       0.153864        0.036211         NaN       0.004446          NaN
# 9220       0.153864        0.036211         NaN       0.004446          NaN
# 9221       0.153864        0.036211         NaN       0.004446          NaN
# 9709       0.378236        0.009096    0.569300       0.008947          NaN
# 9718       0.378236        0.009096    0.569300       0.008947          NaN
# 9951       0.520050             NaN    0.412811       0.014365     0.016200
# 9954       0.520050             NaN    0.412811       0.014365     0.016200
#
#       disgust_score         full_name
# 49         0.049173      DOUG LAMBORN
# 50         0.049173      DOUG LAMBORN
# 254             NaN        DAVID BRAT
# 255             NaN        DAVID BRAT
# 499             NaN    PATRICK MEEHAN
# 500             NaN    PATRICK MEEHAN
# 581             NaN       SAM JOHNSON
# 586             NaN       SAM JOHNSON
# 639        0.027258      DOUG LAMBORN
# 640        0.027518      DOUG LAMBORN
# 1415            NaN     LOUIE GOHMERT
# 1416            NaN     LOUIE GOHMERT
# 2079            NaN      DAN NEWHOUSE
# 2081            NaN      DAN NEWHOUSE
# 2129            NaN      ED WHITFIELD
# 2137            NaN      ED WHITFIELD
# 2445            NaN      DAN NEWHOUSE
# 2446            NaN      DAN NEWHOUSE
# 2860            NaN        SEAN DUFFY
# 2861            NaN        SEAN DUFFY
# 2866            NaN        SEAN DUFFY
# 2868            NaN        SEAN DUFFY
# 3529       0.263469     TIM HUELSKAMP
# 3540       0.057914     TIM HUELSKAMP
# 4685            NaN    JOHN RATCLIFFE
# 4687            NaN    JOHN RATCLIFFE
# 4692            NaN    JOHN RATCLIFFE
# 4693            NaN    JOHN RATCLIFFE
# 5764            NaN       DENNIS ROSS
# 5769            NaN       DENNIS ROSS
# 6530            NaN  MARSHA BLACKBURN
# 6533            NaN  MARSHA BLACKBURN
# 6608            NaN       MARTHA ROBY
# 6612       0.037538       MARTHA ROBY
# 6818            NaN     RAÚL LABRADOR
# 6823            NaN     RAÚL LABRADOR
# 7241            NaN     RAÚL GRIJALVA
# 7242            NaN     RAÚL GRIJALVA
# 7305            NaN   GREGORIO SABLAN
# 7306            NaN   GREGORIO SABLAN
# 7507            NaN   DAVID CICILLINE
# 7513            NaN   DAVID CICILLINE
# 7640            NaN        MARK POCAN
# 7644            NaN        MARK POCAN
# 8293            NaN   MARK DESAULNIER
# 8294            NaN   MARK DESAULNIER
# 8622            NaN      NANCY PELOSI
# 8624            NaN      NANCY PELOSI
# 8862            NaN     RICHARD NOLAN
# 8867            NaN     RICHARD NOLAN
# 9021            NaN   GREGORIO SABLAN
# 9023            NaN   GREGORIO SABLAN
# 9219       0.003973      JOE COURTNEY
# 9220       0.003973      JOE COURTNEY
# 9221       0.003973      JOE COURTNEY
# 9709            NaN     ERIC SWALWELL
# 9718            NaN     ERIC SWALWELL
# 9951            NaN     ERIC SWALWELL
# 9954            NaN     ERIC SWALWELL

# %%
# Drop duplicate records from dcinbox data

dcinbox_emotion_df = dcinbox_emotion_df.drop_duplicates(subset=['Full Name', 'Date', 'Subject'])

dc_dupes = dcinbox_emotion_df[dcinbox_emotion_df.duplicated(subset=["Full Name", "Date", "Subject"], keep=False)]
print("Number of duplicates in dcinbox_emotion_df:", len(dc_dupes))

print("Length of dcinbox_filered_df:", len(dcinbox_emotion_df))
# Out:
# Number of duplicates in dcinbox_emotion_df: 0
# Length of dcinbox_filered_df: 20513

# %%
# Pre-joining QC

# Dcinbox file with counts of newsletters by day
print(len(dcinbox_emotion_df))

# file with politicians matched between dcinbox and FEC data
print(len(matched_pols_df))

# Summary FEC file of candidates and contributions by day
print(len(cand_contribs_df))
# Out:
# 20513
# 396
# 94666

# %%
# Join merged DC Inbox and matched politicians data into a new data frame (left join)

dcinbox_merged_df = dcinbox_emotion_df.merge(
    matched_pols_df,
    left_on = ["Full Name"], # , "State", "District", "Party"],
    right_on = ["dcinbox_name"], # "fec_state", "fec_district", "fec_party"],
    how = 'left'
)

# Drop the columns we don't need
dcinbox_merged_df = dcinbox_merged_df.drop(columns=['fec_state', 'fec_district', 'fec_party', "target_id", "append_attribute2", "append_attribute3",
                                                "matched_scorer", "Party Full", "dcinbox_name", "ID", "similarity_score"])

# Field cleanup & type correction
# dcinbox_merged_df["Date"] == "2020-02-01"
# print(summ_df['fec_cycle'] = dc_inbox_sum_df['fec_cycle'].fillna(0).astype(int)
# dc_inbox_sum_df['similarity_score'] = dc_inbox_sum_df['similarity_score'].fillna(0).astype(int)
dcinbox_merged_df['Date'] = pd.to_datetime(dcinbox_merged_df['Date'])
dcinbox_merged_df = dcinbox_merged_df.rename(columns={'Subject': 'subject'})

# Rename columns so they won't clash with the FEC data file
dcinbox_merged_df = dcinbox_merged_df.rename(columns={
    "Full Name": "dc_name",
    "Date": "dc_date",
    "Congress": "dc_congress",
    "Gender": "dc_gender",
    "State": "dc_state",
    "District": "dc_district",
    "Chamber": "dc_chamber",
    "Party": "dc_party"    
})

print(len(dcinbox_merged_df))
dcinbox_merged_df.head()
# dc_inbox_sum_df.info()
# Out:
# 20513
#                                             subject dc_congress dc_gender  \
# 0                                   Happy New Year!         114         M
# 1                                   Happy New Year!         114         M
# 2  OH-12 Update / A Look Back at the 114th Congress         114         M
# 3              The Leader's Daily Schedule - 1/3/17         114         M
# 4                         What I've Been Working On         114         M
#
#   dc_state  dc_district dc_chamber    dc_date          dc_name dc_party  \
# 0       FL           10      House 2017-01-02   DANIEL WEBSTER        R
# 1       CA           49      House 2017-01-02     DARRELL ISSA        R
# 2       OH           12      House 2017-01-02   PATRICK TIBERI        R
# 3       CA           23      House 2017-01-02   KEVIN MCCARTHY        R
# 4       RI            1      House 2017-01-02  DAVID CICILLINE        D
#
#   newsletter_id  ...  joy_score  neutral_score  surprise_score  fear_score  \
# 0      NL000001  ...        NaN            NaN             NaN         NaN
# 1      NL000002  ...        NaN            NaN             NaN         NaN
# 2      NL000003  ...        NaN            NaN             NaN         NaN
# 3      NL000004  ...        NaN            NaN             NaN         NaN
# 4      NL000005  ...        NaN            NaN             NaN         NaN
#
#    sadness_score  anger_score  disgust_score    fec_cid         fec_name  \
# 0            NaN          NaN            NaN  N00026335   DANIEL WEBSTER
# 1            NaN          NaN            NaN  N00007017     DARRELL ISSA
# 2            NaN          NaN            NaN  N00009699       PAT TIBERI
# 3            NaN          NaN            NaN  N00028152   KEVIN MCCARTHY
# 4            NaN          NaN            NaN  N00032019  DAVID CICILLINE
#
#    fec_cycle
# 0     2016.0
# 1     2016.0
# 2     2016.0
# 3     2016.0
# 4     2016.0
#
# [5 rows x 25 columns]

# %%
# Join summarized FEC and DC Inbox into a new data frame (left join) by day & politician,
# For use in computing rolling window contribution amount & count columns

print(len(dcinbox_merged_df))
print(len(cand_contribs_df))

# Date field type corrections
dcinbox_merged_df['dc_date'] = pd.to_datetime(dcinbox_merged_df['dc_date'])
cand_contribs_df['contrib_date'] = pd.to_datetime(cand_contribs_df['contrib_date'])

window_col_join_df = cand_contribs_df.merge(
# joined_all_df = test_dcinbox_df.merge(
    # dc_inbox_sum_df,
    dcinbox_merged_df.drop(columns=["fec_cycle", "fec_name", "dc_party", "dc_chamber", "dc_district",
                                  "dc_name", "newsletter_count", "body_word_count",
                                  "dc_state", "dc_gender", "dc_congress"]),
    left_on = ['fec_cid', "contrib_date"],
    right_on = ['fec_cid', "dc_date"],
    how = 'left'
)

print(len(window_col_join_df))
window_col_join_df.head()
# dc_inbox_sum_df.info()
# Out:
# 20513
# 94666
# 94773
#    fec_cycle    fec_cid     fec_name fec_party_original no_pacs fec_state  \
# 0       2016  N00030768  MARTHA ROBY                  R                AL
# 1       2016  N00030768  MARTHA ROBY                  R                AL
# 2       2016  N00030768  MARTHA ROBY                  R                AL
# 3       2016  N00030768  MARTHA ROBY                  R                AL
# 4       2016  N00030768  MARTHA ROBY                  R                AL
#
#    fec_district fec_party contrib_date  contrib_count  ...  fundraising_terms  \
# 0             2         R   2015-02-11              1  ...                NaN
# 1             2         R   2015-02-18              2  ...                NaN
# 2             2         R   2015-02-26              1  ...                NaN
# 3             2         R   2015-03-02             26  ...                NaN
# 4             2         R   2015-03-11              1  ...                NaN
#
#   fundraising_ratio  total_newsletters  joy_score neutral_score  \
# 0               NaN                NaN        NaN           NaN
# 1               NaN                NaN        NaN           NaN
# 2               NaN                NaN        NaN           NaN
# 3               NaN                NaN        NaN           NaN
# 4               NaN                NaN        NaN           NaN
#
#   surprise_score fear_score  sadness_score  anger_score  disgust_score
# 0            NaN        NaN            NaN          NaN            NaN
# 1            NaN        NaN            NaN          NaN            NaN
# 2            NaN        NaN            NaN          NaN            NaN
# 3            NaN        NaN            NaN          NaN            NaN
# 4            NaN        NaN            NaN          NaN            NaN
#
# [5 rows x 27 columns]

# %%
# Add a rolling window of a set number of days after the initial newsletter date to the joined FEC/DC Inbox data frame

# Set window days
input_window_days = 2

# Use a small test set at first
# window_col_df = window_col_join_df[window_col_join_df["fec_name"].str.contains("PELOSI")].copy()
# window_col_df = window_col_df[window_col_df["contrib_date"] >= "2019-11-19"].copy()

window_col_df = window_col_join_df.copy()

# Make sure date columns are datetime
window_col_df["contrib_date"] = pd.to_datetime(window_col_df["contrib_date"], errors = "coerce")
window_col_df["dc_date"] = pd.to_datetime(window_col_df["dc_date"], errors = "coerce")

# Fill NaNs in contrib columns to avoid issues during summing
window_col_df["contrib_count"] = window_col_df["contrib_count"].fillna(0).astype(int)
window_col_df["contrib_amount"] = window_col_df["contrib_amount"].fillna(0).astype(int)

# Define the group columns (unique identifiers for rolling sums)
group_cols = ["fec_name", "fec_cycle", "fec_state", "fec_district", "fec_party"]
window_col_df[group_cols] = window_col_df[group_cols].fillna("NA")

# Sort by group and date
window_col_df = window_col_df.sort_values(by = group_cols + ["contrib_date"])

# Define a general rolling window function
def add_forward_rolling_sum(df, value_cols, window_days = input_window_days):
    # value_cols should be a list, e.g. ["contrib_count", "contrib_amount"]
    days_col = "window_days"
    df[days_col] = 0  # initialize shared days column

    for value_col in value_cols:
        new_col = f"window_{value_col}"
        df[new_col] = 0

    for name, g in df.groupby(group_cols, sort=False):
        g = g.sort_values("contrib_date")
        contrib_dates = g["contrib_date"].reset_index(drop=True)
        dates = g["dc_date"].reset_index(drop=True)
        results = {val: np.zeros(len(g), dtype=int) for val in value_cols}
        actual_days = np.zeros(len(g), dtype=int)

        for i, current_date in enumerate(dates):

            if pd.isna(current_date):
                actual_days[i] = 0
                for value_col in value_cols:
                    results[value_col][i] = 0
                continue     

            # Default window end
            window_end = current_date + pd.Timedelta(days=window_days)

            # Include all dates within window initially
            mask = (contrib_dates >= current_date) & (contrib_dates <= window_end)

            # Stop before first non-NaT dc_date if found
            next_reset_idx = np.where((dates > current_date) & pd.notna(dates))[0]
            if len(next_reset_idx) > 0:
                first_reset_date = dates[next_reset_idx[0]]
                mask = mask & (contrib_dates < first_reset_date)
                window_end = min(window_end, first_reset_date - pd.Timedelta(days=1))

            # Store actual number of days used
            actual_days[i] = (window_end - current_date).days + 1

            # Compute rolling sums for all specified value columns
            for value_col in value_cols:
                values = g[value_col].fillna(0).astype(int).reset_index(drop=True)
                results[value_col][i] = int(values[mask].sum())

        # Write results back to df
        for value_col in value_cols:
            new_col = f"window_{value_col}"
            df.loc[g.index, new_col] = results[value_col]
        df.loc[g.index, days_col] = actual_days

    return df


# Compute rolling sums for count and amount
window_col_df = add_forward_rolling_sum(
    window_col_df,
    value_cols=["contrib_count", "contrib_amount"],
    window_days = input_window_days
)

# Check results
# joined_all_window_df.head()[["dc_date", "dc_name", "contrib_count", "window_contrib_count", 
#                              "contrib_amount", "window_contrib_amount"]]
window_col_df.head()

# window_col_nonzero_df = window_col_df[window_col_df["window_contrib_amount"] > 0]
# window_col_nonzero_df.head()
# Out:
#       fec_cycle    fec_cid        fec_name fec_party_original no_pacs  \
# 5710       2016  N00030667  ADAM KINZINGER                  R
# 5711       2016  N00030667  ADAM KINZINGER                  R
# 5712       2016  N00030667  ADAM KINZINGER                  R
# 5713       2016  N00030667  ADAM KINZINGER                  R
# 5714       2016  N00030667  ADAM KINZINGER                  R
#
#      fec_state  fec_district fec_party contrib_date  contrib_count  ...  \
# 5710        IL            16         R   2015-01-22              1  ...
# 5711        IL            16         R   2015-02-03              1  ...
# 5712        IL            16         R   2015-02-05              1  ...
# 5713        IL            16         R   2015-02-09              1  ...
# 5714        IL            16         R   2015-02-12              9  ...
#
#       joy_score neutral_score  surprise_score  fear_score sadness_score  \
# 5710        NaN           NaN             NaN         NaN           NaN
# 5711        NaN           NaN             NaN         NaN           NaN
# 5712        NaN           NaN             NaN         NaN           NaN
# 5713        NaN           NaN             NaN         NaN           NaN
# 5714        NaN           NaN             NaN         NaN           NaN
#
#      anger_score disgust_score  window_days  window_contrib_count  \
# 5710         NaN           NaN            0                     0
# 5711         NaN           NaN            0                     0
# 5712         NaN           NaN            0                     0
# 5713         NaN           NaN            0                     0
# 5714         NaN           NaN            0                     0
#
#       window_contrib_amount
# 5710                      0
# 5711                      0
# 5712                      0
# 5713                      0
# 5714                      0
#
# [5 rows x 30 columns]

# %%
window_col_df.columns
# Out:
# Index(['fec_cycle', 'fec_cid', 'fec_name', 'fec_party_original', 'no_pacs',
#        'fec_state', 'fec_district', 'fec_party', 'contrib_date',
#        'contrib_count', 'contrib_amount', 'month_start',
#        'avg_month_daily_contrib_count', 'avg_month_daily_contrib_amount',
#        'subject', 'dc_date', 'newsletter_id', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters', 'joy_score', 'neutral_score',
#        'surprise_score', 'fear_score', 'sadness_score', 'anger_score',
#        'disgust_score', 'window_days', 'window_contrib_count',
#        'window_contrib_amount'],
#       dtype='object')

# %%
# QC for joining

# test_date = "2015-02-09"
# test_name = "KINZINGER"
test_date = "2016-02-07"
test_name = "SCHIFF"

dcinbox_merged_df['dc_date'] = pd.to_datetime(dcinbox_merged_df['dc_date'])
test_dcinbox_df = dcinbox_merged_df[dcinbox_merged_df["dc_date"] == test_date]
test_dcinbox_df = test_dcinbox_df[test_dcinbox_df["dc_name"].str.contains(test_name)]

cand_contribs_df['contrib_date'] = pd.to_datetime(cand_contribs_df['contrib_date'])
test_fec_df = cand_contribs_df[cand_contribs_df["contrib_date"] == test_date]
test_fec_df = test_fec_df[test_fec_df["fec_name"].str.contains(test_name)]

print(len(test_dcinbox_df))
print(len(test_fec_df))
# test_dcinbox_df.head()
test_fec_df.head()
# Out:
# 0
# 1
#       fec_cycle    fec_cid     fec_name fec_party_original no_pacs fec_state  \
# 2687       2016  N00009585  ADAM SCHIFF                  D                CA
#
#       fec_district fec_party contrib_date  contrib_count  contrib_amount  \
# 2687            28         D   2016-02-07              5            6650
#
#      month_start  avg_month_daily_contrib_count  \
# 2687  2016-02-01                       0.206897
#
#       avg_month_daily_contrib_amount
# 2687                      237.931034

# %%
print(window_col_df.columns)
print(dcinbox_merged_df.columns)
# Out:
# Index(['fec_cycle', 'fec_cid', 'fec_name', 'fec_party_original', 'no_pacs',
#        'fec_state', 'fec_district', 'fec_party', 'contrib_date',
#        'contrib_count', 'contrib_amount', 'month_start',
#        'avg_month_daily_contrib_count', 'avg_month_daily_contrib_amount',
#        'subject', 'dc_date', 'newsletter_id', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters', 'joy_score', 'neutral_score',
#        'surprise_score', 'fear_score', 'sadness_score', 'anger_score',
#        'disgust_score', 'window_days', 'window_contrib_count',
#        'window_contrib_amount'],
#       dtype='object')
# Index(['subject', 'dc_congress', 'dc_gender', 'dc_state', 'dc_district',
#        'dc_chamber', 'dc_date', 'dc_name', 'dc_party', 'newsletter_id',
#        'newsletter_count', 'body_word_count', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters', 'joy_score', 'neutral_score',
#        'surprise_score', 'fear_score', 'sadness_score', 'anger_score',
#        'disgust_score', 'fec_cid', 'fec_name', 'fec_cycle'],
#       dtype='object')

# %%
# Join merged DC Inbox and window-column FEC into a new data frame (left join) by day & politician

print("window_col_df: ", len(window_col_df))
print("dcinbox_merged_df: ", len(dcinbox_merged_df))

# small test set
# dc_inbox_sum_df = dc_inbox_sum_df[dc_inbox_sum_df["dc_name"].str.contains("FINKENAUER")].copy()
# dc_inbox_sum_df = dc_inbox_sum_df[dc_inbox_sum_df["dc_date"] >= "2020-01-30"].copy()

# Merge by politician and date
joined_all_df = dcinbox_merged_df.merge(
    window_col_df.drop(columns  =[
        'fec_cycle', 'fec_name', 'fec_party', 'fec_state', 'fec_district', 'dc_date', 'fundraising_terms', 'total_newsletters', 'fundraising_ratio', 'newsletter_id',
        'subject', 'joy_score', 'neutral_score', 'surprise_score', 'fear_score', 'sadness_score', 'anger_score', 'disgust_score'
    ]),
    left_on = ['fec_cid', 'dc_date'],
    right_on = ['fec_cid', 'contrib_date'],
    how = 'left'
)
print("joined_all_df: ", len(joined_all_df))

# Drop the columns we don't need
# joined_all_df = joined_all_df.drop(columns=['State', 'District', 'Party', "append_attribute2", "append_attribute3"])

# Add score columns normalizing by this month's average daily performance
joined_all_df["month_daily_count_score"] = (
    (joined_all_df["window_contrib_count"] / joined_all_df["window_days"]) /
    joined_all_df["avg_month_daily_contrib_count"]
)
joined_all_df["month_daily_amount_score"] = (
    (joined_all_df["window_contrib_amount"] / joined_all_df["window_days"]) /
    joined_all_df["avg_month_daily_contrib_amount"]
)

# Fill missing values for quantitative columns & format them
num_cols_int = [
    "window_days", "contrib_count", "avg_daily_contrib_count",
    "window_contrib_count", "avg_month_daily_contrib_count"
]
num_cols_float = [
    "contrib_amount", "avg_daily_contrib_amount", "window_contrib_amount",
    "month_daily_count_score", "month_daily_amount_score",
    "avg_month_daily_contrib_amount"
]

# Fill NAs
for col in num_cols_int:
    if col in joined_all_df.columns:
        joined_all_df[col] = joined_all_df[col].fillna(0).astype(int)
for col in num_cols_float:
    if col in joined_all_df.columns:
        joined_all_df[col] = joined_all_df[col].fillna(0).astype(float).map("{:.2f}".format)

# print(dc_inbox_sum_df.columns)
# print(joined_all_df.columns)
joined_all_df.head()
# print(window_col_df.columns)
# Out:
# window_col_df:  94773
# dcinbox_merged_df:  20513
# joined_all_df:  20782
#                                             subject dc_congress dc_gender  \
# 0                                   Happy New Year!         114         M
# 1                                   Happy New Year!         114         M
# 2  OH-12 Update / A Look Back at the 114th Congress         114         M
# 3              The Leader's Daily Schedule - 1/3/17         114         M
# 4                         What I've Been Working On         114         M
#
#   dc_state  dc_district dc_chamber    dc_date          dc_name dc_party  \
# 0       FL           10      House 2017-01-02   DANIEL WEBSTER        R
# 1       CA           49      House 2017-01-02     DARRELL ISSA        R
# 2       OH           12      House 2017-01-02   PATRICK TIBERI        R
# 3       CA           23      House 2017-01-02   KEVIN MCCARTHY        R
# 4       RI            1      House 2017-01-02  DAVID CICILLINE        D
#
#   newsletter_id  ...  contrib_count  contrib_amount  month_start  \
# 0      NL000001  ...              0            0.00          NaT
# 1      NL000002  ...              0            0.00          NaT
# 2      NL000003  ...              0            0.00          NaT
# 3      NL000004  ...              0            0.00          NaT
# 4      NL000005  ...              0            0.00          NaT
#
#    avg_month_daily_contrib_count  avg_month_daily_contrib_amount  window_days  \
# 0                              0                            0.00            0
# 1                              0                            0.00            0
# 2                              0                            0.00            0
# 3                              0                            0.00            0
# 4                              0                            0.00            0
#
#    window_contrib_count  window_contrib_amount  month_daily_count_score  \
# 0                     0                   0.00                     0.00
# 1                     0                   0.00                     0.00
# 2                     0                   0.00                     0.00
# 3                     0                   0.00                     0.00
# 4                     0                   0.00                     0.00
#
#    month_daily_amount_score
# 0                      0.00
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                      0.00
#
# [5 rows x 38 columns]

# %%
# QC for specific Congresspeople

joined_all_qc_df = joined_all_df[joined_all_df["dc_name"] == "ADAM KINZINGER"]
joined_all_qc_df = joined_all_qc_df[
    pd.to_numeric(joined_all_qc_df["month_daily_amount_score"], errors="coerce") > 0
]

joined_all_qc_df.head()
# Out:
#                     subject dc_congress dc_gender dc_state  dc_district  \
# 16378         good morning!         114         M       IL           16
# 17188  around the district          114         M       IL           16
#
#       dc_chamber    dc_date         dc_name dc_party newsletter_id  ...  \
# 16378      House 2015-06-08  ADAM KINZINGER        R      NL019170  ...
# 17188      House 2015-05-13  ADAM KINZINGER        R      NL020099  ...
#
#        contrib_count  contrib_amount  month_start  \
# 16378              4         2269.00   2015-06-01
# 17188              8         9760.00   2015-05-01
#
#        avg_month_daily_contrib_count  avg_month_daily_contrib_amount  \
# 16378                              1                         1525.63
# 17188                              1                         1714.84
#
#        window_days  window_contrib_count  window_contrib_amount  \
# 16378            3                     8                7469.00
# 17188            3                    12               13260.00
#
#        month_daily_count_score  month_daily_amount_score
# 16378                     1.86                      1.63
# 17188                     2.25                      2.58
#
# [2 rows x 38 columns]

# %%
joined_all_df.columns
# Out:
# Index(['subject', 'dc_congress', 'dc_gender', 'dc_state', 'dc_district',
#        'dc_chamber', 'dc_date', 'dc_name', 'dc_party', 'newsletter_id',
#        'newsletter_count', 'body_word_count', 'fundraising_terms',
#        'fundraising_ratio', 'total_newsletters', 'joy_score', 'neutral_score',
#        'surprise_score', 'fear_score', 'sadness_score', 'anger_score',
#        'disgust_score', 'fec_cid', 'fec_name', 'fec_cycle',
#        'fec_party_original', 'no_pacs', 'contrib_date', 'contrib_count',
#        'contrib_amount', 'month_start', 'avg_month_daily_contrib_count',
#        'avg_month_daily_contrib_amount', 'window_days', 'window_contrib_count',
#        'window_contrib_amount', 'month_daily_count_score',
#        'month_daily_amount_score'],
#       dtype='object')

# %%
# Output the final joined file to a CSV file

joined_all_df.to_csv(
    "../data/matched/joined_all_2016.csv",
    index=False  # no row numbers
    # encoding="latin1"
)

# %%
# Parameter sweep to test monthly average count & contribution scores for different window lengths
test_window_days = range(0, 6)
value_cols = ["contrib_count", "contrib_amount"]
window_cols = [f"window_{v}" for v in value_cols]
test_results = []

for days in test_window_days:
    # --- 1. Compute rolling window columns
    temp_df = add_forward_rolling_sum(
        window_col_df.copy(),
        value_cols=value_cols,
        window_days=days
    )

    # --- 2. Merge into DC Inbox summary (this produces "detail" rows)
    joined_all_df = dcinbox_merged_df.merge(
        temp_df.drop(
            columns=[
                "fec_cycle", "fec_name", "fec_party", "fec_state",
                "fec_district", "dc_date", "fundraising_terms",
                "total_newsletters", "fundraising_ratio"
            ],
            errors="ignore"
        ),
        left_on=["fec_cid", "dc_date"],
        right_on=["fec_cid", "contrib_date"],
        how="left"
    )

    # --- 3. Ensure no division by zero
    joined_all_df["window_days"] = joined_all_df["window_days"].replace(0, np.nan)

    # --- 4. Compute month_daily_*_score columns on the detailed rows
    joined_all_df["month_daily_count_score"] = (
        (joined_all_df["window_contrib_count"] / joined_all_df["window_days"]) /
        joined_all_df["avg_month_daily_contrib_count"]
    )
    joined_all_df["month_daily_amount_score"] = (
        (joined_all_df["window_contrib_amount"] / joined_all_df["window_days"]) /
        joined_all_df["avg_month_daily_contrib_amount"]
    )

    # --- 5. Clean up invalid values
    joined_all_df[["month_daily_count_score", "month_daily_amount_score"]] = (
        joined_all_df[["month_daily_count_score", "month_daily_amount_score"]]
        .replace([np.inf, -np.inf], np.nan)
        .fillna(0)
    )

    # --- 6. Ensure date and numeric fields are usable
    joined_all_df["dc_date"] = pd.to_datetime(joined_all_df["dc_date"], errors="coerce")
    joined_all_df["contrib_date"] = pd.to_datetime(joined_all_df["contrib_date"], errors="coerce")

    score_cols = ["month_daily_count_score", "month_daily_amount_score"]
    for col in score_cols:
        joined_all_df[col] = pd.to_numeric(joined_all_df[col], errors="coerce")

    # --- 7. Pull only D and R records
    joined_score_df = joined_all_df[joined_all_df["dc_party"].isin(["D", "R"])].copy()

    # --- 8. Set score columns to 0 where dc_date is NaT
    mask_no_date = joined_score_df["dc_date"].isna()
    joined_score_df.loc[mask_no_date, score_cols] = 0

    # --- 9. Compute monthly averages (grouped by month) for amount and count scores
    joined_score_df["month_year"] = joined_score_df["contrib_date"].dt.to_period("M").dt.to_timestamp()

    monthly_avg_amount = (
        joined_score_df.groupby("month_year")
                       .agg(avg_month_amount=("month_daily_amount_score", "mean"))
                       .reset_index()
    )
    mean_monthly_avg_amount_score = monthly_avg_amount["avg_month_amount"].mean()

    monthly_avg_count = (
        joined_score_df.groupby("month_year")
                       .agg(avg_month_count=("month_daily_count_score", "mean"))
                       .reset_index()
    )
    mean_monthly_avg_count_score = monthly_avg_count["avg_month_count"].mean()

    # --- 10. Summarize results for this window length
    summary = {"input_window_days": days, "window_days": days + 1}
    for col in window_cols:
        summary[col + "_sum"] = temp_df[col].sum()
    summary["mean_monthly_avg_amount_score"] = mean_monthly_avg_amount_score
    summary["mean_monthly_avg_count_score"] = mean_monthly_avg_count_score

    test_results.append(summary)

# Combine into a summary DataFrame
test_summary_df = pd.DataFrame(test_results)

print(test_summary_df)
# Out:
#    input_window_days  window_days  window_contrib_count_sum  \
# 0                  0            1                     60281
# 1                  1            2                     97685
# 2                  2            3                    131841
# 3                  3            4                    166369
# 4                  4            5                    199167
# 5                  5            6                    228213
#
#    window_contrib_amount_sum  mean_monthly_avg_amount_score  \
# 0                   34813633                       3.731384
# 1                   52479066                       2.495344
# 2                   68395396                       2.069708
# 3                   85274684                       1.932939
# 4                  100672792                       1.877783
# 5                  113892916                       1.835073
#
#    mean_monthly_avg_count_score
# 0                      3.613439
# 1                      2.347493
# 2                      1.922953
# 3                      1.762396
# 4                      1.663248
# 5                      1.620159

# %%
# Plot the results of the parameter sweep test

# Create summary table
cols_to_plot = [
    "window_contrib_amount_sum",
    "window_contrib_count_sum",
    "mean_monthly_avg_amount_score",
    "mean_monthly_avg_count_score"
]

# Map column name for title
col_title = {"window_contrib_amount_sum" : "Window contribution amount\nfor newsletters with contributions",
             "window_contrib_count_sum" : "Window contribution count\nfor newsletters with contributions",
             "mean_monthly_avg_amount_score" : "Average window contribution amount score\nfor newsletters with contributions",
             "mean_monthly_avg_count_score" : "Average window contribution count score\nfor newsletters with contributions"}

# Create one plot per metric
for col in cols_to_plot:
    plt.figure(figsize=(5, 3.5))
    plt.plot(
        test_summary_df["window_days"],
        test_summary_df[col],
        marker="o",
        linewidth=2,
        color = breakdown_color1
    )

    # plt.title(f"{col}")
    plt.title(col_title.get(col, col))  # default to column name
    plt.xlabel("Number of days after the newsletter was sent")
    plt.ylabel(col.replace("_", " ").title())
    plt.grid(True, linestyle="-", alpha=0.6)
    plt.tight_layout()
    plt.show()
